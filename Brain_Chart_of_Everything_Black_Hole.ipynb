# %% [markdown]
# <a href="https://colab.research.google.com/github/kevinvandewalker-eng/prismogenesis-whale-hunt/blob/main/Brain_Chart_of_Everything_Black_Hole.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- Set up the grid
g = np.linspace(0.0, 1.5, 200)          # effective coupling (0=no criticality, 1=critical, >1=hyper)
freq = np.logspace(-1, 2, 200)          # frequency from 0.1 Hz to 100 Hz

G, FREQ = np.meshgrid(g, freq)

# --- Boundary lines
# 1. No‑criticality floor (very low coupling, any freq)
g_floor = 0.1 * np.ones_like(freq)

# 2. Critical / edge‑of‑chaos line (g ≈ 1.0, across freqs)
g_critical = 1.0 * np.ones_like(freq)

# 3. Coherence ceiling (high coherence = low effective flexibility, say above 40 Hz)
freq_ceiling = 40.0 * np.ones_like(g)

# --- Figure
plt.figure(figsize=(10, 8))

# Background contour (optional, just to show the space)
plt.contourf(G, FREQ, G, levels=50, cmap="Blues", alpha=0.2)

# Boundary lines
plt.plot(g_floor, freq, '--', color='red', lw=2, label='No‑criticality floor (g ≈ 0.1)')
plt.plot(g_critical, freq, '--', color='red', lw=2, label='Edge‑of‑chaos / critical (g = 1.0)')
plt.plot(g, freq_ceiling, '--', color='red', lw=2, label='Coherence ceiling (freq ≈ 40 Hz)')

# Fill bounded region (near‑critical safe triangle)
plt.fill_between(g, freq, freq_ceiling, where=(g >= 0.1) & (g <= 1.0),
                 color='lightgreen', alpha=0.3, label='Near‑critical "healthy" region')

# Experimental / practice points
plt.scatter([0.88], [1.0], s=100, color='black', label='fMRI near‑critical (g ≈ 0.88)')
plt.scatter([0.5], [0.1], s=100, color='blue', label='0.1 Hz (core‑like slow practice)')
plt.scatter([0.7], [35.], s=100, color='blue', label='35 Hz (mid‑range)')
plt.scatter([0.9], [111.], s=100, color='blue', label='111 Hz (fast horizon practice)')

# Axes and labels
plt.xscale('linear')
plt.yscale('log')
plt.xlabel('Effective coupling $g$ (network energy)', fontsize=12)
plt.ylabel('Temporal scale / frequency (Hz)', fontsize=12)
plt.title('Brain "Chart of Everything"\nBounded by: No‑criticality, Edge‑of‑chaos, and Coherence ceiling',
          fontsize=13)

plt.ylim(0.05, 200)
plt.xlim(0.0, 1.5)
plt.legend(fontsize=10, framealpha=0.9)
plt.grid(True, which='both', alpha=0.3)
plt.tight_layout()

plt.savefig('brain_chart_of_everything.png', dpi=200, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- Set up the grid
g = np.linspace(0.0, 1.5, 200)
freq = np.logspace(-1, 2, 200)

G, FREQ = np.meshgrid(g, freq)

# --- Boundary lines
g_floor = 0.1 * np.ones_like(freq)          # no criticality floor
g_critical = 1.0 * np.ones_like(freq)       # edge‑of‑chaos / critical
freq_ceiling = 40.0 * np.ones_like(g)       # coherence ceiling

# --- Figure
plt.figure(figsize=(10, 8))

plt.contourf(G, FREQ, G, levels=50, cmap="Blues", alpha=0.15)

# --- Boundary lines with labels

# 1. No‑criticality floor
plt.plot(g_floor, freq, '--', color='red', lw=2)
plt.text(0.08, 3, "No‑criticality floor\nisolated noise, no collective scaling",
         color='red', fontsize=10, rotation=0, ha='left', va='top',
         bbox=dict(boxstyle="round,pad=0.3", facecolor='white', alpha=0.8))

# 2. Edge‑of‑chaos / critical line
plt.plot(g_critical, freq, '--', color='red', lw=2)
plt.text(1.05, 3, "Edge of chaos / critical\nrunaway activity possible",
         color='red', fontsize=10, rotation=0, ha='left', va='top',
         bbox=dict(boxstyle="round,pad=0.3", facecolor='white', alpha=0.8))

# 3. Coherence ceiling
plt.plot(g, freq_ceiling, '--', color='red', lw=2)
plt.text(0.6, 45, "Coherence ceiling\nfrozen synchrony, low flexibility",
         color='red', fontsize=10, rotation=0, ha='center',
         bbox=dict(boxstyle="round,pad=0.3", facecolor='white', alpha=0.8))

# --- Near‑critical “healthy” region
plt.fill_between(g, freq, freq_ceiling, where=(g >= 0.1) & (g <= 1.0),
                 color='lightgreen', alpha=0.3)
plt.text(0.5, 10, "Near‑critical healthy regime\nenergy, vibration, frequency in balance",
         color='darkgreen', fontsize=11, ha='center', va='center',
         bbox=dict(boxstyle="round,pad=0.5", facecolor='white', alpha=0.8))

# --- Markers (practice & fMRI)
plt.scatter([0.88], [1.0], s=100, color='black', label='fMRI near‑critical (g ≈ 0.88)')
plt.scatter([0.5], [0.1], s=100, color='blue', label='0.1 Hz (slow core‑like state)')
plt.scatter([0.7], [35.], s=100, color='blue', label='35 Hz (mid‑range)')

# Optional: 111 Hz beyond the log plot, you can annotate it off‑scale
plt.scatter([0.9], [100.], s=100, color='blue', label='111 Hz (fast horizon)')

# --- Axes & title
plt.xscale('linear')
plt.yscale('log')
plt.xlabel('Effective coupling $g$ (network energy)', fontsize=12)
plt.ylabel('Temporal scale / frequency (Hz)', fontsize=12)
plt.title('Brain "Chart of Everything"\nBounded by: no‑criticality, edge‑of‑chaos, and coherence ceiling',
          fontsize=13)

plt.ylim(0.05, 200)
plt.xlim(0.0, 1.5)
plt.legend(fontsize=10, framealpha=0.9, loc='lower right')
plt.grid(True, which='both', alpha=0.3)
plt.tight_layout()

plt.savefig('brain_chart_of_everything_with_labels.png', dpi=200, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- Set up the grid
g = np.linspace(0.0, 1.5, 200)
freq = np.logspace(-1, 2, 200)

G, FREQ = np.meshgrid(g, freq)

# --- Boundary lines
g_floor = 0.1 * np.ones_like(freq)          # no criticality floor
g_critical = 1.0 * np.ones_like(freq)       # edge‑of‑chaos / critical
freq_ceiling = 40.0 * np.ones_like(g)       # coherence ceiling

# --- Figure
plt.figure(figsize=(10, 8))
plt.contourf(G, FREQ, G, levels=50, cmap="Blues", alpha=0.15)

# --- 1. No‑criticality floor
plt.plot(g_floor, freq, '--', color='red', lw=2)
plt.text(0.08, 3, "No‑criticality floor\nisolated noise, no collective scaling",
         color='red', fontsize=10, rotation=0, ha='left', va='top',
         bbox=dict(boxstyle="round,pad=0.3", facecolor='white', alpha=0.8))

# --- 2. Edge‑of‑chaos / critical
plt.plot(g_critical, freq, '--', color='red', lw=2)
plt.text(1.05, 3, "Edge of chaos / critical\nrunaway activity possible",
         color='red', fontsize=10, rotation=0, ha='left', va='top',
         bbox=dict(boxstyle="round,pad=0.3", facecolor='white', alpha=0.8))

# --- 3. Coherence ceiling
plt.plot(g, freq_ceiling, '--', color='red', lw=2)
plt.text(0.6, 45, "Coherence ceiling\nfrozen synchrony, low flexibility",
         color='red', fontsize=10, rotation=0, ha='center',
         bbox=dict(boxstyle="round,pad=0.3", facecolor='white', alpha=0.8))

# --- Near‑critical “healthy” region
plt.fill_between(g, freq, freq_ceiling, where=(g >= 0.1) & (g <= 1.0),
                 color='lightgreen', alpha=0.3, label="Near‑critical healthy regime")

plt.text(0.5, 10, "Near‑critical healthy regime\nenergy, vibration, frequency in balance",
         color='darkgreen', fontsize=11, ha='center', va='center',
         bbox=dict(boxstyle="round,pad=0.5", facecolor='white', alpha=0.8))


# --- Practice markers with distinct colors

# 0.1 Hz (slow, core‑like)
plt.scatter([0.5], [0.1], s=120, color='purple', edgecolor='black', linewidth=1.5,
            label='0.1 Hz – slow core‑like state', zorder=10)

# 35 Hz (mid‑range, mantle‑like)
plt.scatter([0.7], [35.], s=120, color='orange', edgecolor='black', linewidth=1.5,
            label='35 Hz – mid‑range feedback', zorder=10)

# 111 Hz (fast horizon, high‑beta/gamma edge)
plt.scatter([0.9], [111.], s=120, color='hotpink', edgecolor='black', linewidth=1.5,
            label='111 Hz – fast horizon state', zorder=10)

# fMRI near‑critical (empirical anchor point)
plt.scatter([0.88], [1.0], s=120, color='black', edgecolor='black', linewidth=1.5,
            label='fMRI near‑critical (g ≈ 0.88)', zorder=10)


# --- Axes & title
plt.xscale('linear')
plt.yscale('log')
plt.xlabel('Effective coupling $g$ (network energy)', fontsize=12)
plt.ylabel('Temporal scale / frequency (Hz)', fontsize=12)
plt.title('Brain "Chart of Everything"\nBounded by: no‑criticality, edge‑of‑chaos, and coherence ceiling',
          fontsize=13)

plt.ylim(0.05, 200)
plt.xlim(0.0, 1.5)

plt.legend(fontsize=10, framealpha=0.9, loc='lower right')
plt.grid(True, which='both', alpha=0.3, zorder=5)
plt.tight_layout()

plt.savefig('brain_chart_of_everything_with_labels_distinct.png', dpi=200, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import os

# --- Set up the directory for output
os.makedirs('output', exist_ok=True)

# --- Constants & Grid Setup
g_vals = np.linspace(0.0, 1.5, 300)
freq_vals = np.logspace(-1.3, 2.3, 300)
G, FREQ = np.meshgrid(g_vals, freq_vals)

# --- Style Setup (LatticeLogOS Signature Dark Mode)
plt.style.use('dark_background')
fig, ax = plt.subplots(figsize=(12, 9), facecolor='black')
ax.set_facecolor('black')

# --- Background Field (Energy Gradient)
# Subtle radial glow focused near the 111 Hz sync node
# Representing the "Sweet Spot" of lattice resonance
Z = np.exp(-((G - 0.9)**2 / 0.4)) * np.exp(-((np.log10(FREQ) - np.log10(111))**2 / 0.6))
ax.contourf(G, FREQ, Z, levels=60, cmap="magma", alpha=0.25)

# --- Lattice Constraints (Signature Pink #ff0055)
line_color = '#ff0055'
ax.axvline(0.1, color=line_color, lw=3.5, ls='--', alpha=0.9)  # Floor
ax.axvline(1.0, color=line_color, lw=3.5, ls='--', alpha=0.9)  # Edge of Chaos
ax.axhline(40.0, color=line_color, lw=3.5, ls='--', alpha=0.9) # Coherence Ceiling

# --- Highlight Healthy Zone
ax.fill_between([0.1, 1.0], 0.05, 40, color='#00ffcc', alpha=0.1, label="Lattice Sync Zone")

# --- Boxed Annotations (Styled for Video Reveal)
bbox_style = dict(boxstyle="round,pad=0.5", fc="black", ec=line_color, lw=1.5, alpha=0.9)

ax.text(0.12, 0.15, "NO-CRITICALITY FLOOR\n(Isolated Noise)",
        color='white', fontsize=9, fontweight='bold', bbox=bbox_style)
ax.text(1.03, 0.15, "EDGE OF CHAOS\n(Runaway Activity)",
        color='white', fontsize=9, fontweight='bold', bbox=bbox_style)
ax.text(0.5, 48, "COHERENCE CEILING\n(Frozen Synchrony)",
        color='white', fontsize=9, fontweight='bold', ha='center', bbox=bbox_style)

# --- Harmonic Sync Markers (The Nodes)
# 111 Hz Macro Node
ax.scatter([0.9], [111.0], s=500, color='gold', edgecolor='white', lw=3, zorder=20,
           label='111 Hz: Macro Horizon (Sync)')
ax.axhline(111, color='gold', lw=2, alpha=0.3, ls=':')

# 35 Hz Meso Node
ax.scatter([0.7], [35.0], s=350, color='orange', edgecolor='white', lw=2, zorder=15,
           label='35 Hz: Meso Clutch (Feedback)')

# fMRI Anchor
ax.scatter([0.88], [1.0], s=300, color='white', edgecolor='gold', lw=2, zorder=15,
           label='fMRI Anchor (g ≈ 0.88)')

# 0.1 Hz Micro Node
ax.scatter([0.5], [0.1], s=300, color='cyan', edgecolor='white', lw=2, zorder=15,
           label='0.1 Hz: Micro Heartbeat')

# --- Central Brand Focus (The Video Hook)
ax.text(0.55, 6, "HEALTHY REGIME\nLatticeLogOS v11.0\nBio-Cosmic Balance",
         color='#00ffcc', fontsize=15, fontweight='bold', ha='center', va='center',
         bbox=dict(boxstyle="round,pad=1.0", fc="black", ec="#00ffcc", lw=2.5, alpha=0.8))

# --- Axes & Formatting
ax.set_yscale('log')
ax.set_xlim(0, 1.5)
ax.set_ylim(0.05, 250)
ax.set_xlabel('Effective Coupling $g$ (Network Energy)', color='white', fontsize=12, labelpad=12)
ax.set_ylabel('Frequency (Hz)', color='white', fontsize=12, labelpad=12)
ax.set_title('BRAIN "CHART OF EVERYTHING"\n[LatticeLogOS v11.0 Production]',
             color='gold', fontsize=20, fontweight='bold', pad=30)

ax.legend(loc='lower right', facecolor='black', edgecolor='white', fontsize=11, framealpha=0.9)
ax.grid(True, which='both', alpha=0.1, color='white')

plt.tight_layout()
plt.savefig('output/brain_chart_v11.png', dpi=300, facecolor='black')
plt.show()

print("\n✅ LatticeLogOS v11.0 Brain Chart generated in /output/brain_chart_v11.png")
# Out:
# ✅ LatticeLogOS v11.0 Brain Chart generated in /output/brain_chart_v11.png

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- Constants & Grid Setup
g_vals = np.linspace(0.0, 1.5, 300)
freq_vals = np.logspace(-1.3, 2.3, 300)
G, FREQ = np.meshgrid(g_vals, freq_vals)

# --- Style Setup (Signature Dark Mode)
plt.style.use('dark_background')
fig, ax = plt.subplots(figsize=(12, 10), facecolor='black')
ax.set_facecolor('black')

# --- Background Field (Energy Gradient)
Z = np.exp(-((G - 0.9)**2 / 0.4)) * np.exp(-((np.log10(FREQ) - np.log10(111))**2 / 0.6))
ax.contourf(G, FREQ, Z, levels=60, cmap="magma", alpha=0.25)

# --- Lattice Constraints (Signature Pink #ff0055)
line_color = '#ff0055'
ax.axvline(0.1, color=line_color, lw=3.5, ls='--', alpha=0.9)  # Floor
ax.axvline(1.0, color=line_color, lw=3.5, ls='--', alpha=0.9)  # Edge of Chaos
ax.axhline(40.0, color=line_color, lw=3.5, ls='--', alpha=0.9) # Coherence Ceiling

# --- Highlight Healthy Zone
ax.fill_between([0.1, 1.0], 0.05, 40, color='#00ffcc', alpha=0.1, label="Lattice Sync Zone")

# --- Boxed Annotations (Repositioned to Avoid Legend)
bbox_style = dict(boxstyle="round,pad=0.5", fc="black", ec=line_color, lw=1.5, alpha=0.9)

ax.text(0.12, 0.15, "NO-CRITICALITY\nFLOOR",
        color='white', fontsize=10, fontweight='bold', bbox=bbox_style)
ax.text(1.03, 0.15, "EDGE OF CHAOS\n(RUNAWAY)",
        color='white', fontsize=10, fontweight='bold', bbox=bbox_style)
ax.text(0.5, 48, "COHERENCE CEILING (FROZEN)",
        color='white', fontsize=10, fontweight='bold', ha='center', bbox=bbox_style)

# --- Harmonic Sync Markers
ax.scatter([0.9], [111.0], s=500, color='gold', edgecolor='white', lw=3, zorder=20,
           label='111 Hz: Macro Horizon')
ax.axhline(111, color='gold', lw=2, alpha=0.3, ls=':')

ax.scatter([0.7], [35.0], s=350, color='orange', edgecolor='white', lw=2, zorder=15,
           label='35 Hz: Meso Clutch')

ax.scatter([0.88], [1.0], s=300, color='white', edgecolor='gold', lw=2, zorder=15,
           label='fMRI Anchor (g ≈ 0.88)')

ax.scatter([0.5], [0.1], s=300, color='cyan', edgecolor='white', lw=2, zorder=15,
           label='0.1 Hz: Micro Heartbeat')

# --- Central Brand Focus
ax.text(0.55, 6, "HEALTHY REGIME\nLatticeLogOS v11.0\nBio-Cosmic Balance",
         color='#00ffcc', fontsize=16, fontweight='bold', ha='center', va='center',
         bbox=dict(boxstyle="round,pad=1.0", fc="black", ec="#00ffcc", lw=2.5, alpha=0.8))

# --- Axes & Formatting
ax.set_yscale('log')
ax.set_xlim(0, 1.5)
ax.set_ylim(0.05, 350) # Increased ceiling slightly for legend clearance
ax.set_xlabel('Effective Coupling $g$ (Network Energy)', color='white', fontsize=14, labelpad=12)
ax.set_ylabel('Frequency (Hz)', color='white', fontsize=14, labelpad=12)
ax.set_title('BRAIN "CHART OF EVERYTHING"\n[LatticeLogOS v11.0 Production]',
             color='gold', fontsize=22, fontweight='bold', pad=30)

# --- Legend Fix (Moved to Upper Left)
ax.legend(loc='upper left', facecolor='black', edgecolor='white', fontsize=11, framealpha=0.95)
ax.grid(True, which='both', alpha=0.1, color='white')

plt.tight_layout()

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- Constants & Grid Setup
g_vals = np.linspace(0.0, 1.5, 300)
freq_vals = np.logspace(-1.3, 2.3, 300)  # 0.05 Hz → 200 Hz
G, FREQ = np.meshgrid(g_vals, freq_vals)

# --- Style Setup (Signature Dark Mode)
plt.style.use('dark_background')
fig, ax = plt.subplots(figsize=(12, 10), facecolor='black')
ax.set_facecolor('black')

# --- Background Field (Energy Gradient)
Z = (
    np.exp(-((G - 0.9)**2 / 0.4)) *
    np.exp(-((np.log10(FREQ) - np.log10(111))**2 / 0.6))
)
ax.contourf(G, FREQ, Z, levels=60, cmap='magma', alpha=0.25)

# --- Lattice Constraints (Signature Pink #ff0055)
line_color = '#ff0055'
ax.axvline(0.1, color=line_color, lw=3.5, ls='--', alpha=0.9)   # Floor
ax.axvline(1.0, color=line_color, lw=3.5, ls='--', alpha=0.9)   # Edge of Chaos
ax.axhline(40.0, color=line_color, lw=3.5, ls='--', alpha=0.9)  # Coherence Ceiling

# --- Healthy Zone (Lattice Sync Zone)
ax.fill_between([0.1, 1.0], 0.05, 40, color='#00ffcc', alpha=0.1)

# --- Boxed Annotations (Repositioned for clarity)
bbox_style = dict(
    boxstyle="round,pad=0.5",
    fc="black",
    ec=line_color,
    lw=1.5,
    alpha=0.9
)

ax.text(
    0.12,
    0.18,
    "NO-CRITICALITY\nFLOOR",
    color='white',
    fontsize=10,
    fontweight='bold',
    ha='left',
    bbox=bbox_style
)

ax.text(
    1.04,
    0.18,
    "EDGE OF CHAOS\n(RUNAWAY)",
    color='white',
    fontsize=10,
    fontweight='bold',
    ha='left',
    bbox=bbox_style
)

ax.text(
    0.5,
    55,
    "COHERENCE\nCEILING (FROZEN)",
    color='white',
    fontsize=10,
    fontweight='bold',
    ha='center',
    bbox=bbox_style
)

# --- Harmonic Sync Markers
ax.scatter(
    [0.9], [111.0],
    s=500,
    color='gold',
    edgecolor='white',
    lw=3,
    zorder=20,
    label='111 Hz: Macro Horizon (Sync)'
)
ax.axhline(
    111,
    color='gold',
    lw=2,
    alpha=0.3,
    ls=':'
)

ax.scatter(
    [0.7], [35.0],
    s=350,
    color='orange',
    edgecolor='white',
    lw=2,
    zorder=15,
    label='35 Hz: Meso Clutch (Feedback)'
)

ax.scatter(
    [0.88], [1.0],
    s=300,
    color='white',
    edgecolor='gold',
    lw=2,
    zorder=15,
    label='fMRI Anchor (g ≈ 0.88)'
)

ax.scatter(
    [0.5], [0.1],
    s=300,
    color='cyan',
    edgecolor='white',
    lw=2,
    zorder=15,
    label='0.1 Hz: Micro Heartbeat'
)

# --- Central Brand Focus (less crowded position)
ax.text(
    0.55,
    4.5,
    "HEALTHY REGIME\nLatticeLogOS v11.0",
    color='#00ffcc',
    fontsize=16,
    fontweight='bold',
    ha='center',
    va='center',
    bbox=dict(
        boxstyle="round,pad=0.8",
        fc="black",
        ec="#00ffcc",
        lw=2.5,
        alpha=0.8
    )
)

# --- Axes & Formatting
ax.set_yscale('log')
ax.set_xlim(0.0, 1.5)
ax.set_ylim(0.05, 350)

ax.set_xlabel(
    'Effective Coupling $g$ (Network Energy)',
    color='white',
    fontsize=14,
    labelpad=12
)
ax.set_ylabel(
    'Frequency (Hz)',
    color='white',
    fontsize=14,
    labelpad=12
)

ax.set_title(
    'BRAIN "CHART OF EVERYTHING"\n[LatticeLogOS v11.0 Production]',
    color='gold',
    fontsize=22,
    fontweight='bold',
    pad=30
)

# --- Legend (Moved outside top right, slightly smaller font)
ax.legend(
    loc='upper right',
    bbox_to_anchor=(1.02, 1.0),
    handlelength=1.5,
    facecolor='black',
    edgecolor='white',
    fontsize=11,
    framealpha=0.95
)

ax.grid(True, which='both', alpha=0.1, color='white')
plt.tight_layout(rect=[0, 0, 0.95, 0.95])

plt.savefig('output/brain_chart_v11_clean.png', dpi=300, facecolor='black')
plt.show()

# %%
Here’s your cleaned code again, with the two‑line caption embedded as a comment right above the chart‑generation block, so you can keep it as documentation:

python
import matplotlib.pyplot as plt
import numpy as np

# === BRAIN "CHART OF EVERYTHING" ===
# Caption for chart (use under image or in README / video):
#
#   The Brain "Chart of Everything" maps the Healthy Regime where the human brain
#   lives near, but not at, criticality. It shows how 0.1 Hz, 35 Hz, and 111 Hz
#   align with the floor, edge‑of‑chaos, and coherence ceiling of network energy and frequency.
#

# --- Constants & Grid Setup
g_vals = np.linspace(0.0, 1.5, 300)
freq_vals = np.logspace(-1.3, 2.3, 300)  # 0.05 Hz → 200 Hz
G, FREQ = np.meshgrid(g_vals, freq_vals)

# --- Style Setup (Signature Dark Mode)
plt.style.use('dark_background')
fig, ax = plt.subplots(figsize=(12, 10), facecolor='black')
ax.set_facecolor('black')

# --- Background Field (Energy Gradient)
Z = (
    np.exp(-((G - 0.9)**2 / 0.4)) *
    np.exp(-((np.log10(FREQ) - np.log10(111))**2 / 0.6))
)
ax.contourf(G, FREQ, Z, levels=60, cmap='magma', alpha=0.25)

# --- Lattice Constraints (Signature Pink #ff0055)
line_color = '#ff0055'
ax.axvline(0.1, color=line_color, lw=3.5, ls='--', alpha=0.9)   # Floor
ax.axvline(1.0, color=line_color, lw=3.5, ls='--', alpha=0.9)   # Edge of Chaos
ax.axhline(40.0, color=line_color, lw=3.5, ls='--', alpha=0.9)  # Coherence Ceiling

# --- Healthy Zone (Lattice Sync Zone)
ax.fill_between([0.1, 1.0], 0.05, 40, color='#00ffcc', alpha=0.1)

# --- Boxed Annotations (Repositioned for clarity)
bbox_style = dict(
    boxstyle="round,pad=0.5",
    fc="black",
    ec=line_color,
    lw=1.5,
    alpha=0.9
)

ax.text(
    0.12,
    0.18,
    "NO-CRITICALITY\nFLOOR",
    color='white',
    fontsize=10,
    fontweight='bold',
    ha='left',
    bbox=bbox_style
)

ax.text(
    1.04,
    0.18,
    "EDGE OF CHAOS\n(RUNAWAY)",
    color='white',
    fontsize=10,
    fontweight='bold',
    ha='left',
    bbox=bbox_style
)

ax.text(
    0.5,
    55,
    "COHERENCE\nCEILING (FROZEN)",
    color='white',
    fontsize=10,
    fontweight='bold',
    ha='center',
    bbox=bbox_style
)

# --- Harmonic Sync Markers
ax.scatter(
    [0.9], [111.0],
    s=500,
    color='gold',
    edgecolor='white',
    lw=3,
    zorder=20,
    label='111 Hz: Macro Horizon (Sync)'
)
ax.axhline(
    111,
    color='gold',
    lw=2,
    alpha=0.3,
    ls=':'
)

ax.scatter(
    [0.7], [35.0],
    s=350,
    color='orange',
    edgecolor='white',
    lw=2,
    zorder=15,
    label='35 Hz: Meso Clutch (Feedback)'
)

ax.scatter(
    [0.88], [1.0],
    s=300,
    color='white',
    edgecolor='gold',
    lw=2,
    zorder=15,
    label='fMRI Anchor (g ≈ 0.88)'
)

ax.scatter(
    [0.5], [0.1],
    s=300,
    color='cyan',
    edgecolor='white',
    lw=2,
    zorder=15,
    label='0.1 Hz: Micro Heartbeat'
)

# --- Central Brand Focus (less crowded position)
ax.text(
    0.55,
    4.5,
    "HEALTHY REGIME\nLatticeLogOS v11.0",
    color='#00ffcc',
    fontsize=16,
    fontweight='bold',
    ha='center',
    va='center',
    bbox=dict(
        boxstyle="round,pad=0.8",
        fc="black",
        ec="#00ffcc",
        lw=2.5,
        alpha=0.8
    )
)

# --- Axes & Formatting
ax.set_yscale('log')
ax.set_xlim(0.0, 1.5)
ax.set_ylim(0.05, 350)

ax.set_xlabel(
    'Effective Coupling $g$ (Network Energy)',
    color='white',
    fontsize=14,
    labelpad=12
)
ax.set_ylabel(
    'Frequency (Hz)',
    color='white',
    fontsize=14,
    labelpad=12
)

ax.set_title(
    'BRAIN "CHART OF EVERYTHING"\n[LatticeLogOS v11.0 Production]',
    color='gold',
    fontsize=22,
    fontweight='bold',
    pad=30
)

# --- Legend (Moved outside top right)
ax.legend(
    loc='upper right',
    bbox_to_anchor=(1.02, 1.0),
    handlelength=1.5,
    facecolor='black',
    edgecolor='white',
    fontsize=11,
    framealpha=0.95
)

ax.grid(True, which='both', alpha=0.1, color='white')
plt.tight_layout(rect=[0, 0, 0.95, 0.95])

plt.savefig('output/brain_chart_v11_clean.png', dpi=300, facecolor='black')
plt.show()
# Out:
#   File "/tmp/ipykernel_7582/1657097795.py", line 1
#     Here’s your cleaned code again, with the two‑line caption embedded as a comment right above the chart‑generation block, so you can keep it as documentation:
#         ^
# SyntaxError: invalid character '’' (U+2019)

# %%
import matplotlib.pyplot as plt
import numpy as np

# === BRAIN "CHART OF EVERYTHING" ===
# Caption for chart (use under image or in README / video):
#
#   The Brain "Chart of Everything" maps the Healthy Regime where the human brain
#   lives near, but not at, criticality. It shows how 0.1 Hz, 35 Hz, and 111 Hz
#   align with the floor, edge‑of‑chaos, and coherence ceiling of network energy and frequency.
#

# --- Constants & Grid Setup
g_vals = np.linspace(0.0, 1.5, 300)
freq_vals = np.logspace(-1.3, 2.3, 300)  # 0.05 Hz → 200 Hz
G, FREQ = np.meshgrid(g_vals, freq_vals)

# --- Style Setup (Signature Dark Mode)
plt.style.use('dark_background')
fig, ax = plt.subplots(figsize=(12, 10), facecolor='black')
ax.set_facecolor('black')

# --- Background Field (Energy Gradient)
Z = (
    np.exp(-((G - 0.9)**2 / 0.4)) *
    np.exp(-((np.log10(FREQ) - np.log10(111))**2 / 0.6))
)
ax.contourf(G, FREQ, Z, levels=60, cmap='magma', alpha=0.25)

# --- Lattice Constraints (Signature Pink #ff0055)
line_color = '#ff0055'
ax.axvline(0.1, color=line_color, lw=3.5, ls='--', alpha=0.9)   # Floor
ax.axvline(1.0, color=line_color, lw=3.5, ls='--', alpha=0.9)   # Edge of Chaos
ax.axhline(40.0, color=line_color, lw=3.5, ls='--', alpha=0.9)  # Coherence Ceiling

# --- Healthy Zone (Lattice Sync Zone)
ax.fill_between([0.1, 1.0], 0.05, 40, color='#00ffcc', alpha=0.1)

# --- Boxed Annotations (Repositioned for clarity)
bbox_style = dict(
    boxstyle="round,pad=0.5",
    fc="black",
    ec=line_color,
    lw=1.5,
    alpha=0.9
)

ax.text(
    0.12,
    0.18,
    "NO-CRITICALITY\nFLOOR",
    color='white',
    fontsize=10,
    fontweight='bold',
    ha='left',
    bbox=bbox_style
)

ax.text(
    1.04,
    0.18,
    "EDGE OF CHAOS\n(RUNAWAY)",
    color='white',
    fontsize=10,
    fontweight='bold',
    ha='left',
    bbox=bbox_style
)

ax.text(
    0.5,
    55,
    "COHERENCE\nCEILING (FROZEN)",
    color='white',
    fontsize=10,
    fontweight='bold',
    ha='center',
    bbox=bbox_style
)

# --- Harmonic Sync Markers
ax.scatter(
    [0.9], [111.0],
    s=500,
    color='gold',
    edgecolor='white',
    lw=3,
    zorder=20,
    label='111 Hz: Macro Horizon (Sync)'
)
ax.axhline(
    111,
    color='gold',
    lw=2,
    alpha=0.3,
    ls=':'
)

ax.scatter(
    [0.7], [35.0],
    s=350,
    color='orange',
    edgecolor='white',
    lw=2,
    zorder=15,
    label='35 Hz: Meso Clutch (Feedback)'
)

ax.scatter(
    [0.88], [1.0],
    s=300,
    color='white',
    edgecolor='gold',
    lw=2,
    zorder=15,
    label='fMRI Anchor (g ≈ 0.88)'
)

ax.scatter(
    [0.5], [0.1],
    s=300,
    color='cyan',
    edgecolor='white',
    lw=2,
    zorder=15,
    label='0.1 Hz: Micro Heartbeat'
)

# --- Central Brand Focus (less crowded position)
ax.text(
    0.55,
    4.5,
    "HEALTHY REGIME\nLatticeLogOS v11.0",
    color='#00ffcc',
    fontsize=16,
    fontweight='bold',
    ha='center',
    va='center',
    bbox=dict(
        boxstyle="round,pad=0.8",
        fc="black",
        ec="#00ffcc",
        lw=2.5,
        alpha=0.8
    )
)

# --- Axes & Formatting
ax.set_yscale('log')
ax.set_xlim(0.0, 1.5)
ax.set_ylim(0.05, 350)

ax.set_xlabel(
    'Effective Coupling $g$ (Network Energy)',
    color='white',
    fontsize=14,
    labelpad=12
)
ax.set_ylabel(
    'Frequency (Hz)',
    color='white',
    fontsize=14,
    labelpad=12
)

ax.set_title(
    'BRAIN "CHART OF EVERYTHING"\n[LatticeLogOS v11.0 Production]',
    color='gold',
    fontsize=22,
    fontweight='bold',
    pad=30
)

# --- Legend (Moved outside top right)
ax.legend(
    loc='upper right',
    bbox_to_anchor=(1.02, 1.0),
    handlelength=1.5,
    facecolor='black',
    edgecolor='white',
    fontsize=11,
    framealpha=0.95
)

ax.grid(True, which='both', alpha=0.1, color='white')
plt.tight_layout(rect=[0, 0, 0.95, 0.95])

plt.savefig('output/brain_chart_v11_clean.png', dpi=300, facecolor='black')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- Constants & Grid Setup
g_vals = np.linspace(0.0, 1.5, 300)
freq_vals = np.logspace(-1.3, 2.3, 300)  # 0.05 Hz → 200 Hz
G, FREQ = np.meshgrid(g_vals, freq_vals)

# --- Style Setup (Signature Dark Mode)
plt.style.use('dark_background')
fig, ax = plt.subplots(figsize=(12, 10), facecolor='black')
ax.set_facecolor('black')

# --- Background Field (Energy Gradient)
Z = (
    np.exp(-((G - 0.9)**2 / 0.4)) *
    np.exp(-((np.log10(FREQ) - np.log10(111))**2 / 0.6))
)
ax.contourf(G, FREQ, Z, levels=60, cmap='magma', alpha=0.25)

# --- Lattice Constraints (Signature Pink #ff0055)
line_color = '#ff0055'
ax.axvline(0.1, color=line_color, lw=3.5, ls='--', alpha=0.9)   # Floor
ax.axvline(1.0, color=line_color, lw=3.5, ls='--', alpha=0.9)   # Edge of Chaos
ax.axhline(40.0, color=line_color, lw=3.5, ls='--', alpha=0.9)  # Coherence Ceiling

# --- Healthy Zone (Lattice Sync Zone)
ax.fill_between([0.1, 1.0], 0.05, 40, color='#00ffcc', alpha=0.1)

# --- Boxed Annotations (Repositioned for clarity)
bbox_style = dict(
    boxstyle="round,pad=0.5",
    fc="black",
    ec=line_color,
    lw=1.5,
    alpha=0.9
)

ax.text(
    0.12,
    0.18,
    "NO-CRITICALITY\nFLOOR",
    color='white',
    fontsize=10,
    fontweight='bold',
    ha='left',
    bbox=bbox_style
)

ax.text(
    1.04,
    0.18,
    "EDGE OF CHAOS\n(RUNAWAY)",
    color='white',
    fontsize=10,
    fontweight='bold',
    ha='left',
    bbox=bbox_style
)

ax.text(
    0.5,
    55,
    "COHERENCE\nCEILING (FROZEN)",
    color='white',
    fontsize=10,
    fontweight='bold',
    ha='center',
    bbox=bbox_style
)

# --- Harmonic Sync Markers
ax.scatter(
    [0.9], [111.0],
    s=500,
    color='gold',
    edgecolor='white',
    lw=3,
    zorder=20,
    label='111 Hz: Macro Horizon (Sync)'
)
ax.axhline(
    111,
    color='gold',
    lw=2,
    alpha=0.3,
    ls=':'
)

ax.scatter(
    [0.7], [35.0],
    s=350,
    color='orange',
    edgecolor='white',
    lw=2,
    zorder=15,
    label='35 Hz: Meso Clutch (Feedback)'
)

ax.scatter(
    [0.88], [1.0],
    s=300,
    color='white',
    edgecolor='gold',
    lw=2,
    zorder=15,
    label='fMRI Anchor (g ≈ 0.88)'
)

ax.scatter(
    [0.5], [0.1],
    s=300,
    color='cyan',
    edgecolor='white',
    lw=2,
    zorder=15,
    label='0.1 Hz: Micro Heartbeat'
)

# --- Central Brand Focus (less crowded position)
ax.text(
    0.55,
    4.5,
    "HEALTHY REGIME\nLatticeLogOS v11.0",
    color='#00ffcc',
    fontsize=16,
    fontweight='bold',
    ha='center',
    va='center',
    bbox=dict(
        boxstyle="round,pad=0.8",
        fc="black",
        ec="#00ffcc",
        lw=2.5,
        alpha=0.8
    )
)

# --- Axes & Formatting
ax.set_yscale('log')
ax.set_xlim(0.0, 1.5)
ax.set_ylim(0.05, 350)

ax.set_xlabel(
    'Effective Coupling $g$ (Network Energy)',
    color='white',
    fontsize=14,
    labelpad=12
)
ax.set_ylabel(
    'Frequency (Hz)',
    color='white',
    fontsize=14,
    labelpad=12
)

ax.set_title(
    'BRAIN "CHART OF EVERYTHING"\n[LatticeLogOS v11.0 Production]',
    color='gold',
    fontsize=22,
    fontweight='bold',
    pad=30
)

# --- Legend (Moved outside top right)
ax.legend(
    loc='upper right',
    bbox_to_anchor=(1.02, 1.0),
    handlelength=1.5,
    facecolor='black',
    edgecolor='white',
    fontsize=11,
    framealpha=0.95
)

ax.grid(True, which='both', alpha=0.1, color='white')

# --- Caption text on the chart (bottom)
ax.text(
    0.02,
    0.015,
    "The Brain \"Chart of Everything\" maps the Healthy Regime where the\n"
    "human brain lives near, but not at, criticality. It shows how 0.1 Hz,\n"
    "35 Hz, and 111 Hz align with the floor, edge‑of‑chaos, and coherence\n"
    "ceiling of network energy and frequency.",
    transform=ax.transAxes,
    color='white',
    fontsize=9,
    alpha=0.8,
    ha='left',
    va='bottom',
    bbox=dict(boxstyle="round,pad=0.3", fc="black", ec="white", lw=0.8, alpha=0.7)
)

plt.tight_layout(rect=[0, 0, 1.0, 1.0])  # Keep caption fully visible
plt.savefig('output/brain_chart_v11_with_caption.png', dpi=300, facecolor='black')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- Constants & Grid Setup
g_vals = np.linspace(0.0, 1.5, 300)
freq_vals = np.logspace(-1.3, 2.3, 300)  # 0.05 Hz → 200 Hz
G, FREQ = np.meshgrid(g_vals, freq_vals)

# --- Style Setup (Signature Dark Mode)
plt.style.use('dark_background')
fig, ax = plt.subplots(figsize=(12, 10), facecolor='black')
ax.set_facecolor('black')

# --- Background Field (Energy Gradient)
Z = (
    np.exp(-((G - 0.9)**2 / 0.4)) *
    np.exp(-((np.log10(FREQ) - np.log10(111))**2 / 0.6))
)
ax.contourf(G, FREQ, Z, levels=60, cmap='magma', alpha=0.25)

# --- Lattice Constraints (Signature Pink #ff0055)
line_color = '#ff0055'
ax.axvline(0.1, color=line_color, lw=3.5, ls='--', alpha=0.9)   # Floor
ax.axvline(1.0, color=line_color, lw=3.5, ls='--', alpha=0.9)   # Edge of Chaos
ax.axhline(40.0, color=line_color, lw=3.5, ls='--', alpha=0.9)  # Coherence Ceiling

# --- Healthy Zone (Lattice Sync Zone)
ax.fill_between([0.1, 1.0], 0.05, 40, color='#00ffcc', alpha=0.1)

# --- Boxed Annotations (Repositioned for clarity)
bbox_style = dict(
    boxstyle="round,pad=0.5",
    fc="black",
    ec=line_color,
    lw=1.5,
    alpha=0.9
)

ax.text(
    0.12,
    0.18,
    "NO-CRITICALITY\nFLOOR",
    color='white',
    fontsize=10,
    fontweight='bold',
    ha='left',
    bbox=bbox_style
)

ax.text(
    1.04,
    0.18,
    "EDGE OF CHAOS\n(RUNAWAY)",
    color='white',
    fontsize=10,
    fontweight='bold',
    ha='left',
    bbox=bbox_style
)

ax.text(
    0.5,
    55,
    "COHERENCE\nCEILING (FROZEN)",
    color='white',
    fontsize=10,
    fontweight='bold',
    ha='center',
    bbox=bbox_style
)

# --- Harmonic Sync Markers
ax.scatter(
    [0.9], [111.0],
    s=500,
    color='gold',
    edgecolor='white',
    lw=3,
    zorder=20,
    label='111 Hz: Macro Horizon (Sync)'
)
ax.axhline(
    111,
    color='gold',
    lw=2,
    alpha=0.3,
    ls=':'
)

ax.scatter(
    [0.7], [35.0],
    s=350,
    color='orange',
    edgecolor='white',
    lw=2,
    zorder=15,
    label='35 Hz: Meso Clutch (Feedback)'
)

ax.scatter(
    [0.88], [1.0],
    s=300,
    color='white',
    edgecolor='gold',
    lw=2,
    zorder=15,
    label='fMRI Anchor (g ≈ 0.88)'
)

ax.scatter(
    [0.5], [0.1],
    s=300,
    color='cyan',
    edgecolor='white',
    lw=2,
    zorder=15,
    label='0.1 Hz: Micro Heartbeat'
)

# --- Central Brand Focus (less crowded position)
ax.text(
    0.55,
    4.5,
    "HEALTHY REGIME\nLatticeLogOS v11.0",
    color='#00ffcc',
    fontsize=16,
    fontweight='bold',
    ha='center',
    va='center',
    bbox=dict(
        boxstyle="round,pad=0.8",
        fc="black",
        ec="#00ffcc",
        lw=2.5,
        alpha=0.8
    )
)

# --- Axes & Formatting
ax.set_yscale('log')
ax.set_xlim(0.0, 1.5)
ax.set_ylim(0.05, 350)

ax.set_xlabel(
    'Effective Coupling $g$ (Network Energy)',
    color='white',
    fontsize=14,
    labelpad=12
)
ax.set_ylabel(
    'Frequency (Hz)',
    color='white',
    fontsize=14,
    labelpad=12
)

ax.set_title(
    'BRAIN "CHART OF EVERYTHING"\n[LatticeLogOS v11.0 Production]',
    color='gold',
    fontsize=22,
    fontweight='bold',
    pad=30
)

# --- Legend (Moved outside top right)
ax.legend(
    loc='upper right',
    bbox_to_anchor=(1.02, 1.0),
    handlelength=1.5,
    facecolor='black',
    edgecolor='white',
    fontsize=11,
    framealpha=0.95
)

ax.grid(True, which='both', alpha=0.1, color='white')

# --- Caption text on the chart (bottom, shorter‑taller box, wider)
ax.text(
    0.02,
    0.025,
    "The Brain \"Chart of Everything\" maps the Healthy Regime where the\n"
    "human brain lives near, but not at, criticality. It shows how 0.1 Hz,\n"
    "35 Hz, and 111 Hz align with the floor, edge‑of‑chaos, and coherence\n"
    "ceiling of network energy and frequency.",
    transform=ax.transAxes,
    color='white',
    fontsize=9,
    alpha=0.8,
    ha='left',
    va='center',
    bbox=dict(boxstyle="round,pad=0.15", fc="black", ec="white", lw=0.8, alpha=0.7)
)

plt.tight_layout(rect=[0, 0, 1.0, 1.0])
plt.savefig('output/brain_chart_v11_caption_box_tighter.png', dpi=300, facecolor='black')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- Constants & Grid Setup
g_vals = np.linspace(0.0, 1.5, 300)
freq_vals = np.logspace(-1.3, 2.3, 300)  # 0.05 Hz → 200 Hz
G, FREQ = np.meshgrid(g_vals, freq_vals)

# --- Style Setup (Signature Dark Mode)
plt.style.use('dark_background')
fig, ax = plt.subplots(figsize=(12, 10), facecolor='black')
ax.set_facecolor('black')

# --- Background Field (Energy Gradient)
Z = (
    np.exp(-((G - 0.9)**2 / 0.4)) *
    np.exp(-((np.log10(FREQ) - np.log10(111))**2 / 0.6))
)
ax.contourf(G, FREQ, Z, levels=60, cmap='magma', alpha=0.25)

# --- Lattice Constraints (Signature Pink #ff0055)
line_color = '#ff0055'
ax.axvline(0.1, color=line_color, lw=3.5, ls='--', alpha=0.9)   # Floor
ax.axvline(1.0, color=line_color, lw=3.5, ls='--', alpha=0.9)   # Edge of Chaos
ax.axhline(40.0, color=line_color, lw=3.5, ls='--', alpha=0.9)  # Coherence Ceiling

# --- Healthy Zone (Lattice Sync Zone)
ax.fill_between([0.1, 1.0], 0.05, 40, color='#00ffcc', alpha=0.1)

# --- Boxed Annotations (Repositioned for clarity)
bbox_style = dict(
    boxstyle="round,pad=0.5",
    fc="black",
    ec=line_color,
    lw=1.5,
    alpha=0.9
)

ax.text(
    0.12,
    0.18,
    "NO-CRITICALITY\nFLOOR",
    color='white',
    fontsize=10,
    fontweight='bold',
    ha='left',
    bbox=bbox_style
)

ax.text(
    1.04,
    0.18,
    "EDGE OF CHAOS\n(RUNAWAY)",
    color='white',
    fontsize=10,
    fontweight='bold',
    ha='left',
    bbox=bbox_style
)

ax.text(
    0.5,
    55,
    "COHERENCE\nCEILING (FROZEN)",
    color='white',
    fontsize=10,
    fontweight='bold',
    ha='center',
    bbox=bbox_style
)

# --- Harmonic Sync Markers
ax.scatter(
    [0.9], [111.0],
    s=500,
    color='gold',
    edgecolor='white',
    lw=3,
    zorder=20,
    label='111 Hz: Macro Horizon (Sync)'
)
ax.axhline(
    111,
    color='gold',
    lw=2,
    alpha=0.3,
    ls=':'
)

ax.scatter(
    [0.7], [35.0],
    s=350,
    color='orange',
    edgecolor='white',
    lw=2,
    zorder=15,
    label='35 Hz: Meso Clutch (Feedback)'
)

ax.scatter(
    [0.88], [1.0],
    s=300,
    color='white',
    edgecolor='gold',
    lw=2,
    zorder=15,
    label='fMRI Anchor (g ≈ 0.88)'
)

ax.scatter(
    [0.5], [0.1],
    s=300,
    color='cyan',
    edgecolor='white',
    lw=2,
    zorder=15,
    label='0.1 Hz: Micro Heartbeat'
)

# --- Central Brand Focus (less crowded position)
ax.text(
    0.55,
    4.5,
    "HEALTHY REGIME\nLatticeLogOS v11.0",
    color='#00ffcc',
    fontsize=16,
    fontweight='bold',
    ha='center',
    va='center',
    bbox=dict(
        boxstyle="round,pad=0.8",
        fc="black",
        ec="#00ffcc",
        lw=2.5,
        alpha=0.8
    )
)

# --- Axes & Formatting
ax.set_yscale('log')
ax.set_xlim(0.0, 1.5)
ax.set_ylim(0.05, 350)

ax.set_xlabel(
    'Effective Coupling $g$ (Network Energy)',
    color='white',
    fontsize=14,
    labelpad=12
)
ax.set_ylabel(
    'Frequency (Hz)',
    color='white',
    fontsize=14,
    labelpad=12
)

ax.set_title(
    'BRAIN "CHART OF EVERYTHING"\n[LatticeLogOS v11.0 Production]',
    color='gold',
    fontsize=22,
    fontweight='bold',
    pad=30
)

# --- Legend (Moved outside top right)
ax.legend(
    loc='upper right',
    bbox_to_anchor=(1.02, 1.0),
    handlelength=1.5,
    facecolor='black',
    edgecolor='white',
    fontsize=11,
    framealpha=0.95
)

ax.grid(True, which='both', alpha=0.1, color='white')

# --- Caption text stretched out and placed between the two red dotted vertical lines
ax.text(
    0.5,
    0.015,
    "The Brain \"Chart of Everything\" maps the Healthy Regime where the human brain lives near, but not at, criticality.\n"
    "It shows how 0.1 Hz, 35 Hz, and 111 Hz align with the floor, edge‑of‑chaos, and coherence ceiling of network energy and frequency.",
    transform=ax.transAxes,
    color='white',
    fontsize=10,
    alpha=0.9,
    ha='center',
    va='bottom',
    bbox=dict(boxstyle="round,pad=0.3,rounding_size=0.05", fc="black", ec="white", lw=1, alpha=0.8)
)

plt.tight_layout(rect=[0, 0, 1.0, 1.0])
plt.savefig('output/brain_chart_v11_caption_between_lines.png', dpi=300, facecolor='black')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# === SPINNING vs NON-SPINNING BLACK HOLE LATTICE CHART ===

plt.style.use('dark_background')
fig, ax = plt.subplots(2, 1, figsize=(12, 10), sharex=True, facecolor='black')
ax[0].set_facecolor('black')
ax[1].set_facecolor('black')

# --- Panel 1: Radial spacetime lattice (Geometry / Horizons)

ax[0].set_ylabel('Radial Structure\n(Lattice Depth)', color='white', fontsize=12)

# Non-spinning (Schwarzschild)
horizon_sch = 1.0
ax[0].axvline(horizon_sch, color='cyan', lw=4, alpha=0.8,
              label='Non-spinning (Schwarzschild) Horizon')
ax[0].fill_betweenx([0, 1.6], 0, 1.0, color='cyan', alpha=0.1)
ax[0].text(0.95, 0.2, 'Spherical Sink\nNo twist', color='cyan', fontsize=10, ha='right')

# Spinning (Kerr)
horizon_outer_kerr = 0.6
horizon_inner_kerr = 0.4
ax[0].axvline(horizon_outer_kerr, color='orange', lw=4, alpha=0.8,
              label='Spinning (Kerr) Outer Horizon')
ax[0].axvline(horizon_inner_kerr, color='gold', lw=3, alpha=0.7,
              label='Kerr Inner Horizon')
ax[0].fill_betweenx([0, 1.6], 0, 0.6, color='orange', alpha=0.1)
ax[0].text(0.35, 0.2, 'Twisted Ergosphere\nRing Singularity', color='orange', fontsize=10, ha='center')

ax[0].axhline(0, color='white', lw=0.8, alpha=0.3)
ax[0].axhline(1.6, color='white', lw=0.8, alpha=0.3)
ax[0].set_xlim(0, 1.2)
ax[0].set_title('Spacetime Lattice Structure:\nNon-Spinning vs Spinning Black Hole',
                color='gold', fontsize=14, pad=10)
ax[0].legend(facecolor='black', edgecolor='white', fontsize=10, loc='upper right')
ax[0].grid(True, alpha=0.1, color='white')

# --- Panel 2: Time Dilation / Lattice Clock Drag

ax[1].set_xlabel('Distance from Central Node (Normalized)', color='white', fontsize=12)
ax[1].set_ylabel('Lattice Clock Drag\n(Time Dilation Factor)', color='white', fontsize=12)

r = np.linspace(0.1, 1.2, 200)

# Non-spinning (Schwarzschild-like radial time dilation)
time_sch = 1.0 - 1.0 / (r**1.5 + 1)
ax[1].plot(r, time_sch, color='cyan', lw=2.5,
           label='Non-spinning: Radial Time Dilation')

# Spinning (Kerr-like, extra drag near horizon)
time_kerr = 1.0 - 1.0 / ((r - 0.4)**2 + 0.1)
time_kerr_bounded = np.clip(time_kerr, 0.0, 1.0)
ax[1].plot(r, time_kerr_bounded, color='orange', lw=2.5,
           label='Spinning: Frame-dragging + Time Twist')

ax[1].axvline(0.6, color='orange', lw=1.5, alpha=0.5, ls='--', zorder=1)
ax[1].axvline(0.4, color='gold', lw=1.5, alpha=0.5, ls=':', zorder=1)

ax[1].text(0.7, 0.8, 'Möbius-Knot Time Twist\n(Ergosphere, Ring Core)',
           color='orange', fontsize=10, ha='left')
ax[1].text(0.2, 0.3, 'Static Radial Lattice\n111 Hz Anchor Node',
           color='cyan', fontsize=10, ha='left')

ax[1].set_xlim(0, 1.2)
ax[1].set_title('Lattice Time Dilation:\nRadial vs Twisted Coordinates',
                color='gold', fontsize=14, pad=10)
ax[1].legend(facecolor='black', edgecolor='white', fontsize=10, loc='upper right')
ax[1].grid(True, alpha=0.1, color='white')

plt.tight_layout(pad=2.0)
plt.savefig('black_hole_lattice_comparative_chart.png', dpi=300, facecolor='black')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# === BLACK HOLE LATTICE CHART: SPINNING vs NON-SPINNING + DENSITY FLOOR ===
plt.style.use('dark_background')
fig, ax = plt.subplots(2, 1, figsize=(12, 10), sharex=True, facecolor='black')
ax[0].set_facecolor('black')
ax[1].set_facecolor('black')

# --- Panel 1: Radial spacetime lattice (Geometry / Horizons)
ax[0].set_ylabel('Radial Structure\n(Lattice Depth)', color='white', fontsize=12)

# Non-spinning (Schwarzschild)
horizon_sch = 1.0
ax[0].axvline(horizon_sch, color='cyan', lw=4, alpha=0.8,
              label='Non-spinning (Schwarzschild) Horizon')
ax[0].fill_betweenx([0, 1.6], 0, 1.0, color='cyan', alpha=0.1)
ax[0].text(0.95, 0.2, 'Spherical Sink\nNo twist', color='cyan', fontsize=10, ha='right')

# Spinning (Kerr)
horizon_outer_kerr = 0.6
horizon_inner_kerr = 0.4
ax[0].axvline(horizon_outer_kerr, color='orange', lw=4, alpha=0.8,
              label='Spinning (Kerr) Outer Horizon')
ax[0].axvline(horizon_inner_kerr, color='gold', lw=3, alpha=0.7,
              label='Kerr Inner Horizon')
ax[0].fill_betweenx([0, 1.6], 0, 0.6, color='orange', alpha=0.1)
ax[0].text(0.35, 0.2, 'Twisted Ergosphere\nRing Singularity', color='orange', fontsize=10, ha='center')

ax[0].axhline(0, color='white', lw=0.8, alpha=0.3)
ax[0].axhline(1.6, color='white', lw=0.8, alpha=0.3)
ax[0].set_xlim(0, 1.2)
ax[0].set_title('Spacetime Lattice Structure:\nNon-Spinning vs Spinning Black Hole',
                color='gold', fontsize=14, pad=10)
ax[0].legend(facecolor='black', edgecolor='white', fontsize=10, loc='upper right')
ax[0].grid(True, alpha=0.1, color='white')

# --- Panel 2: Time Dilation / Lattice Clock Drag + Density Floor
ax[1].set_xlabel('Distance from Central Node (Normalized)', color='white', fontsize=12)
ax[1].set_ylabel('Lattice Clock Drag\n(Time Dilation Factor)', color='white', fontsize=12)

r = np.linspace(0.1, 1.2, 200)

# Non-spinning radial time dilation
time_sch = 1.0 - 1.0 / (r**1.5 + 1)
ax[1].plot(r, time_sch, color='cyan', lw=2.5,
           label='Non-spinning: Radial Time Dilation')

# Spinning frame-dragging / twist
time_kerr = 1.0 - 1.0 / ((r - 0.4)**2 + 0.1)
time_kerr_bounded = np.clip(time_kerr, 0.0, 1.0)
ax[1].plot(r, time_kerr_bounded, color='orange', lw=2.5,
           label='Spinning: Frame-dragging + Time Twist')

# --- Black Hole Density Floor (Lattice Core Floor)
ax[1].axhline(0.5, color='#ff0055', lw=2, alpha=0.8,
              ls='--', label='Lattice Core Floor [$\\rho \\approx 10^{15} \\text{kg/m}^3$]')

ax[1].text(0.15, 0.52, 'Black Hole Density Floor',
           color='#ff0055', fontsize=9,
           ha='left', bbox=dict(boxstyle="round,pad=0.2", fc="black", ec="#ff0055"))

ax[1].axvline(0.6, color='orange', lw=1.5, alpha=0.5, ls='--', zorder=1)
ax[1].axvline(0.4, color='gold', lw=1.5, alpha=0.5, ls=':', zorder=1)

ax[1].text(0.7, 0.8, 'Möbius-Knot Time Twist\n(Ergosphere, Ring Core)',
           color='orange', fontsize=10, ha='left')
ax[1].text(0.2, 0.3, 'Static Radial Lattice\n111 Hz Anchor Node',
           color='cyan', fontsize=10, ha='left')

ax[1].set_xlim(0, 1.2)
ax[1].set_title('Lattice Time Dilation & Density Floor:\nRadial vs Twisted Coordinates',
                color='gold', fontsize=14, pad=10)
ax[1].legend(facecolor='black', edgecolor='white', fontsize=10, loc='lower right')
ax[1].grid(True, alpha=0.1, color='white')

plt.tight_layout(pad=2.0)
plt.savefig('black_hole_lattice_comparative_chart_with_floor.png', dpi=300, facecolor='black')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# === BLACK HOLE LATTICE CHART: SPINNING vs NON-SPINNING + DENSITY FLOOR ===
plt.style.use('dark_background')
fig, ax = plt.subplots(2, 1, figsize=(12, 10), sharex=True, facecolor='black')
ax[0].set_facecolor('black')
ax[1].set_facecolor('black')

# --- Panel 1: Radial spacetime lattice (Geometry / Horizons)
ax[0].set_ylabel('Radial Structure\n(Lattice Depth)', color='white', fontsize=12)

# Non-spinning (Schwarzschild)
horizon_sch = 1.0
ax[0].axvline(horizon_sch, color='cyan', lw=4, alpha=0.8,
              label='Non-spinning (Schwarzschild) Horizon')
ax[0].fill_betweenx([0, 1.6], 0, 1.0, color='cyan', alpha=0.1)
ax[0].text(0.95, 0.2, 'Spherical Sink\nNo twist', color='cyan', fontsize=10, ha='right')

# Spinning (Kerr)
horizon_outer_kerr = 0.6
horizon_inner_kerr = 0.4
ax[0].axvline(horizon_outer_kerr, color='orange', lw=4, alpha=0.8,
              label='Spinning (Kerr) Outer Horizon')
ax[0].axvline(horizon_inner_kerr, color='gold', lw=3, alpha=0.7,
              label='Kerr Inner Horizon')
ax[0].fill_betweenx([0, 1.6], 0, 0.6, color='orange', alpha=0.1)
ax[0].text(0.35, 0.2, 'Twisted Ergosphere\nRing Singularity', color='orange', fontsize=10, ha='center')

ax[0].axhline(0, color='white', lw=0.8, alpha=0.3)
ax[0].axhline(1.6, color='white', lw=0.8, alpha=0.3)
ax[0].set_xlim(0, 1.2)
ax[0].set_title('Spacetime Lattice Structure:\nNon-Spinning vs Spinning Black Hole',
                color='gold', fontsize=14, pad=10)
ax[0].legend(facecolor='black', edgecolor='white', fontsize=10, loc='upper right')
ax[0].grid(True, alpha=0.1, color='white')

# --- Panel 2: Time Dilation / Lattice Clock Drag + Density Floor
ax[1].set_xlabel('Distance from Central Node (Normalized)', color='white', fontsize=12)
ax[1].set_ylabel('Lattice Clock Drag\n(Time Dilation Factor)', color='white', fontsize=12)

r = np.linspace(0.1, 1.2, 200)

# Non-spinning radial time dilation
time_sch = 1.0 - 1.0 / (r**1.5 + 1)
ax[1].plot(r, time_sch, color='cyan', lw=2.5,
           label='Non-spinning: Radial Time Dilation')

# Spinning frame-dragging / twist
time_kerr = 1.0 - 1.0 / ((r - 0.4)**2 + 0.1)
time_kerr_bounded = np.clip(time_kerr, 0.0, 1.0)
ax[1].plot(r, time_kerr_bounded, color='orange', lw=2.5,
           label='Spinning: Frame-dragging + Time Twist')

# --- Black Hole Density Floor (Lattice Core Floor)
ax[1].axhline(0.5, color='#ff0055', lw=2, alpha=0.8,
              ls='--', label='Lattice Core Floor [$\\rho \\approx 10^{15} \\text{kg/m}^3$]')

ax[1].text(0.15, 0.52, 'Black Hole Density Floor',
           color='#ff0055', fontsize=9,
           ha='left', bbox=dict(boxstyle="round,pad=0.2", fc="black", ec="#ff0055"))

ax[1].axvline(0.6, color='orange', lw=1.5, alpha=0.5, ls='--', zorder=1)
ax[1].axvline(0.4, color='gold', lw=1.5, alpha=0.5, ls=':', zorder=1)

ax[1].text(0.7, 0.8, 'Möbius-Knot Time Twist\n(Ergosphere, Ring Core)',
           color='orange', fontsize=10, ha='left')
ax[1].text(0.2, 0.3, 'Static Radial Lattice\n111 Hz Anchor Node',
           color='cyan', fontsize=10, ha='left')

ax[1].set_xlim(0, 1.2)
ax[1].set_title('Lattice Time Dilation & Density Floor:\nRadial vs Twisted Coordinates',
                color='gold', fontsize=14, pad=10)
ax[1].legend(facecolor='black', edgecolor='white', fontsize=10, loc='lower right')
ax[1].grid(True, alpha=0.1, color='white')

plt.tight_layout(pad=2.0)
plt.savefig('black_hole_lattice_comparative_chart_with_floor.png', dpi=300, facecolor='black')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- Constants & Style Setup
plt.style.use('dark_background')
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 13), facecolor='black') # Slightly taller for header

# Color Palette
color_static = '#00f2ff'   # Cyan (Schwarzschild)
color_outer = '#ff9900'    # Orange (Kerr Outer)
color_inner = '#ffcc00'    # Yellow (Kerr Inner)
color_floor = '#ff3366'    # Pink (Lattice Floor)
color_torsion = '#ffcc00'  # Gold (Stored Torsion)

# --- TOP CHART: SPACETIME LATTICE STRUCTURE
ax1.set_facecolor('black')

# Horizon Markers (Normalized)
rs_schwarz = 1.0
rs_kerr_outer = 0.6
rs_kerr_inner = 0.4

# Vertical Lines
ax1.axvline(rs_schwarz, color=color_static, lw=4, label='Non-spinning (Schwarzschild) Horizon')
ax1.axvline(rs_kerr_outer, color=color_outer, lw=4, label='Spinning (Kerr) Outer Horizon')
ax1.axvline(rs_kerr_inner, color=color_inner, lw=4, label='Kerr Inner Horizon')

# 1. 18-Minute Torsion Buffer Shading
ax1.axvspan(rs_kerr_inner, rs_kerr_outer, color=color_outer, alpha=0.15,
            label='18-Minute Torsion Buffer (Ergosphere)')

# Text Annotations
ax1.text(0.15, 0.4, 'TWISTED ERGOSPHERE\nMöbius-Knot Time Twist', color=color_outer, fontsize=10, ha='left')
ax1.text(0.8, 0.4, 'SPHERICAL SINK\nStatic Lattice', color=color_static, fontsize=10, ha='left')

# Formatting Top
ax1.set_xlim(0, 1.2)
ax1.set_ylim(-0.1, 1.7)
ax1.set_ylabel('Radial Structure\n(Lattice Depth)', fontsize=12, labelpad=15)
ax1.set_title('LatticeLogOS Theory: INFINITY KILLER v11.0\nSpacetime Lattice Structure: Non-Spinning vs Spinning Black Hole',
             color='gold', fontsize=18, fontweight='bold', pad=25)
ax1.legend(loc='upper right', frameon=True, facecolor='black', edgecolor='white', fontsize=10)
ax1.grid(True, alpha=0.1)

# --- BOTTOM CHART: LATTICE TIME DILATION & DENSITY FLOOR
ax2.set_facecolor('black')

r = np.linspace(0.05, 1.2, 500)

# Static Radial Lattice (Schwarzschild-like dilation)
y_static = 1 / (r + 1.2)

# Stored Torsion (The Dark Sector Battery Curve)
y_torsion = 0.05 * np.log(r + 0.1) + 0.1
y_torsion[y_torsion < 0] = 0

# 2. 111 Hz Harmonic Ripple at the Floor (The Solid-State transition)
floor_val = 0.5
ax2.axhline(floor_val, color=color_floor, lw=3, ls='--', label='Lattice Core Floor [ρ ≈ 10¹⁵ kg/m³]')

# Find intersection for ripple placement
ripple_r = np.linspace(0.7, 0.9, 100)
ripple_y = floor_val + 0.02 * np.sin(2 * np.pi * 11.1 * (ripple_r - 0.8))
ax2.plot(ripple_r, ripple_y, color='white', lw=2, zorder=5)
ax2.text(0.8, 0.55, '111 Hz SOLID-STATE\nTERMINATION', color='white', fontsize=9, ha='center')

# Plotting Curves
ax2.plot(r, y_static, color=color_static, lw=4, label='Static Radial Lattice (111 Hz Anchor)')
ax2.plot(r, y_torsion, color=color_torsion, lw=3, label='Stored Torsion (Dark Sector Battery)')

# Shading the Battery Gap
ax2.fill_between(r, y_torsion, y_static, where=(y_static > y_torsion),
                 color=color_static, alpha=0.08, label='Angular Momentum Charge (L)')

# Formatting Bottom
ax2.set_xlim(0, 1.2)
ax2.set_ylim(-0.05, 0.65)
ax2.set_xlabel('Distance from Central Node (Normalized)', fontsize=12, labelpad=10)
ax2.set_ylabel('Lattice Clock Drag\n(Time Dilation Factor)', fontsize=12, labelpad=15)
ax2.set_title('LatticeLogOS Theory: Lattice Time Dilation & Density Floor\nRadial vs Twisted Coordinates',
             color='gold', fontsize=16, fontweight='bold', pad=20)
ax2.legend(loc='lower right', frameon=True, facecolor='black', edgecolor='white', fontsize=9)
ax2.grid(True, alpha=0.1)

# Central Branding Box
ax2.text(0.4, 0.25, '111 Hz SOLID-STATE NODE\n[LatticeLogOS Infinity Killer]',
         color=color_floor, fontsize=14, fontweight='bold', ha='center',
         bbox=dict(boxstyle="round,pad=0.5", fc="black", ec=color_floor, lw=2))

plt.tight_layout()
plt.savefig('lattice_logos_black_hole_v11.png', dpi=300, facecolor='black')
plt.show()

print("\n✅ LatticeLogOS v11.0 Theory Blueprint with full branding generated.")
# Out:
# ✅ LatticeLogOS v11.0 Theory Blueprint with full branding generated.

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- Constants & Style Setup
plt.style.use('dark_background')
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 13), facecolor='black')  # Slightly taller for header

# Color Palette
color_static = '#00f2ff'   # Cyan (Schwarzschild)
color_outer  = '#ff9900'   # Orange (Kerr Outer)
color_inner  = '#ffcc00'   # Yellow (Kerr Inner)
color_floor  = '#ff3366'   # Pink (Lattice Floor)
color_torsion = '#ffcc00'  # Gold (Stored Torsion)

# --- TOP CHART: SPACETIME LATTICE STRUCTURE
ax1.set_facecolor('black')

# Horizon Markers (Normalized)
rs_schwarz   = 1.0
rs_kerr_outer = 0.6
rs_kerr_inner = 0.4

# Vertical Lines
ax1.axvline(rs_schwarz,   color=color_static, lw=4, label='Non-spinning (Schwarzschild) Horizon')
ax1.axvline(rs_kerr_outer, color=color_outer,  lw=4, label='Spinning (Kerr) Outer Horizon')
ax1.axvline(rs_kerr_inner, color=color_inner,  lw=4, label='Kerr Inner Horizon')

# 1. 18‑Minute Torsion Buffer Shading (Ergosphere)
ax1.axvspan(rs_kerr_inner, rs_kerr_outer, color=color_outer, alpha=0.15,
            label='18‑Minute Torsion Buffer (Ergosphere)')

# Text Annotations
ax1.text(0.15, 0.4, 'TWISTED ERGOSPHERE\nMöbius‑Knot Time Twist',
         color=color_outer, fontsize=10, ha='left')
ax1.text(0.8,  0.4, 'SPHERICAL SINK\nStatic Lattice',
         color=color_static, fontsize=10, ha='left')

# Formatting Top
ax1.set_xlim(0, 1.2)
ax1.set_ylim(-0.1, 1.7)

ax1.set_ylabel('Radial Structure\n(Lattice Depth)', fontsize=12, labelpad=15)
ax1.set_title('LatticeLogOS Theory: INFINITY KILLER v11.0\n'
              'Spacetime Lattice Structure: Non‑Spinning vs Spinning Black Hole',
              color='gold', fontsize=18, fontweight='bold', pad=25)

ax1.legend(loc='upper right', frameon=True, facecolor='black', edgecolor='white', fontsize=10)
ax1.grid(True, alpha=0.1)

# --- BOTTOM CHART: LATTICE TIME DILATION & DENSITY FLOOR
ax2.set_facecolor('black')

r = np.linspace(0.05, 1.2, 500)

# Static Radial Lattice (Schwarzschild‑like dilation)
y_static = 1 / (r + 1.2)

# Stored Torsion (The Dark Sector Battery Curve)
y_torsion = 0.05 * np.log(r + 0.1) + 0.1
y_torsion[y_torsion < 0] = 0

# 2. 111 Hz Harmonic Ripple at the Floor (Solid‑State Transition)
floor_val = 0.5
ax2.axhline(floor_val, color=color_floor, lw=3, ls='--',
            label='Lattice Core Floor [ρ ≈ 10¹⁵ kg/m³]')

# Ripple placement
ripple_r = np.linspace(0.7, 0.9, 100)
ripple_y = floor_val + 0.02 * np.sin(2 * np.pi * 11.1 * (ripple_r - 0.8))
ax2.plot(ripple_r, ripple_y, color='white', lw=2, zorder=5)

ax2.text(0.8, 0.55, '111 Hz SOLID‑STATE\nTERMINATION',
         color='white', fontsize=9, ha='center')

# Plotting Curves
ax2.plot(r, y_static, color=color_static,  lw=4,
         label='Static Radial Lattice (111 Hz Anchor)')
ax2.plot(r, y_torsion, color=color_torsion, lw=3,
         label='Stored Torsion (Dark Sector Battery)')

# Shading the Battery Gap
ax2.fill_between(r, y_torsion, y_static, where=(y_static > y_torsion),
                 color=color_static, alpha=0.08, label='Angular Momentum Charge (L)')

# Formatting Bottom
ax2.set_xlim(0, 1.2)
ax2.set_ylim(-0.05, 0.65)

ax2.set_xlabel('Distance from Central Node (Normalized)', fontsize=12, labelpad=10)
ax2.set_ylabel('Lattice Clock Drag\n(Time Dilation Factor)', fontsize=12, labelpad=15 diferente)

ax2.set_title('LatticeLogOS Theory: Lattice Time Dilation & Density Floor\n'
              'Radial vs Twisted Coordinates',
              color='gold', fontsize=16, fontweight='bold', pad=20)

ax2.legend(loc='lower right', frameon=True, facecolor='black', edgecolor='white', fontsize=9)
ax2.grid(True, alpha=0.1)

# Central Branding Box
ax2.text(0.4, 0.25,
         '111 Hz SOLID‑STATE NODE\n[LatticeLogOS Infinity Killer]',
         color=color_floor, fontsize=14, fontweight='bold', ha='center',
         bbox=dict(boxstyle="round,pad=0.5", fc="black", ec=color_floor, lw=2))

plt.tight_layout(pad=2.5)
plt.savefig('lattice_logos_black_hole_v11.png', dpi=300, facecolor='black')
plt.show()

print("\n✅ LatticeLogOS v11.0 Theory Blueprint with full branding generated.")
# Out:
#   File "/tmp/ipykernel_7582/741984515.py", line 90
#     ax2.set_ylabel('Lattice Clock Drag\n(Time Dilation Factor)', fontsize=12, labelpad=15 diferente)
#                                                                                        ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- Constants & Style Setup
plt.style.use('dark_background')
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 13), facecolor='black')  # Slightly taller for header

# Color Palette
color_static = '#00f2ff'   # Cyan (Schwarzschild)
color_outer  = '#ff9900'   # Orange (Kerr Outer)
color_inner  = '#ffcc00'   # Yellow (Kerr Inner)
color_floor  = '#ff3366'   # Pink (Lattice Floor)
color_torsion = '#ffcc00'  # Gold (Stored Torsion)

# --- TOP CHART: SPACETIME LATTICE STRUCTURE
ax1.set_facecolor('black')

# Horizon Markers (Normalized)
rs_schwarz   = 1.0
rs_kerr_outer = 0.6
rs_kerr_inner = 0.4

# Vertical Lines
ax1.axvline(rs_schwarz,   color=color_static, lw=4, label='Non-spinning (Schwarzschild) Horizon')
ax1.axvline(rs_kerr_outer, color=color_outer,  lw=4, label='Spinning (Kerr) Outer Horizon')
ax1.axvline(rs_kerr_inner, color=color_inner,  lw=4, label='Kerr Inner Horizon')

# 1. 18‑Minute Torsion Buffer Shading (Ergosphere)
ax1.axvspan(rs_kerr_inner, rs_kerr_outer, color=color_outer, alpha=0.15,
            label='18‑Minute Torsion Buffer (Ergosphere)')

# Text Annotations
ax1.text(0.15, 0.4, 'TWISTED ERGOSPHERE\nMöbius‑Knot Time Twist',
         color=color_outer, fontsize=10, ha='left')
ax1.text(0.8,  0.4, 'SPHERICAL SINK\nStatic Lattice',
         color=color_static, fontsize=10, ha='left')

# Formatting Top
ax1.set_xlim(0, 1.2)
ax1.set_ylim(-0.1, 1.7)

ax1.set_xlabel('Distance from Central Node (Normalized)', fontsize=12, labelpad=10)
ax1.set_ylabel('Radial Structure\n(Lattice Depth)', fontsize=12, labelpad=15)
ax1.set_title('LatticeLogOS Theory: INFINITY KILLER v11.0\n'
              'Spacetime Lattice Structure: Non‑Spinning vs Spinning Black Hole',
              color='gold', fontsize=18, fontweight='bold', pad=25)

ax1.legend(loc='upper right', frameon=True, facecolor='black', edgecolor='white', fontsize=10)
ax1.grid(True, alpha=0.1)

# --- BOTTOM CHART: LATTICE TIME DILATION & DENSITY FLOOR
ax2.set_facecolor('black')

r = np.linspace(0.05, 1.2, 500)

# Static Radial Lattice (Schwarzschild‑like dilation)
y_static = 1 / (r + 1.2)

# Stored Torsion (The Dark Sector Battery Curve)
y_torsion = 0.05 * np.log(r + 0.1) + 0.1
y_torsion[y_torsion < 0] = 0

# 2. 111 Hz Harmonic Ripple at the Floor (Solid‑State Transition)
floor_val = 0.5
ax2.axhline(floor_val, color=color_floor, lw=3, ls='--',
            label='Lattice Core Floor [ρ ≈ 10¹⁵ kg/m³]')

# Ripple placement
ripple_r = np.linspace(0.7, 0.9, 100)
ripple_y = floor_val + 0.02 * np.sin(2 * np.pi * 11.1 * (ripple_r - 0.8))
ax2.plot(ripple_r, ripple_y, color='white', lw=2, zorder=5)

ax2.text(0.8, 0.55, '111 Hz SOLID‑STATE\nTERMINATION',
         color='white', fontsize=9, ha='center')

# Plotting Curves
ax2.plot(r, y_static, color=color_static,  lw=4,
         label='Static Radial Lattice (111 Hz Anchor)')
ax2.plot(r, y_torsion, color=color_torsion, lw=3,
         label='Stored Torsion (Dark Sector Battery)')

# Shading the Battery Gap
ax2.fill_between(r, y_torsion, y_static, where=(y_static > y_torsion),
                 color=color_static, alpha=0.08, label='Angular Momentum Charge (L)')

# Formatting Bottom
ax2.set_xlim(0, 1.2)
ax2.set_ylim(-0.05, 0.65)

ax2.set_xlabel('Distance from Central Node (Normalized)', fontsize=12, labelpad=10)
ax2.set_ylabel('Lattice Clock Drag\n(Time Dilation Factor)', fontsize=12, labelpad=15)

ax2.set_title('LatticeLogOS Theory: Lattice Time Dilation & Density Floor\n'
              'Radial vs Twisted Coordinates',
              color='gold', fontsize=16, fontweight='bold', pad=20)

ax2.legend(loc='lower right', frameon=True, facecolor='black', edgecolor='white', fontsize=9)
ax2.grid(True, alpha=0.1)

# Central Branding Box
ax2.text(0.4, 0.25,
         '111 Hz SOLID‑STATE NODE\n[LatticeLogOS Infinity Killer]',
         color=color_floor, fontsize=14, fontweight='bold', ha='center',
         bbox=dict(boxstyle="round,pad=0.5", fc="black", ec=color_floor, lw=2))

plt.tight_layout(pad=2.5)
plt.savefig('lattice_logos_black_hole_v11.png', dpi=300, facecolor='black')
plt.show()

print("\n✅ LatticeLogOS v11.0 Theory Blueprint with full branding generated.")
# Out:
# ✅ LatticeLogOS v11.0 Theory Blueprint with full branding generated.
