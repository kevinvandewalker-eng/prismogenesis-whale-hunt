# %% [markdown]
# <a href="https://colab.research.google.com/github/kevinvandewalker-eng/prismogenesis-whale-hunt/blob/main/LatticelogOS_Pulse_Phase_Map.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
python
import matplotlib.pyplot as plt
import numpy as np

# --- Constants & Lattice Parameters ---
G = 6.67430e-11  # Gravitational Constant
c = 299792458    # Speed of Light
h = 6.62607e-34  # Planck Constant
kappa = 9.009e-4 # User Coupling Constant
f_backbone = 111 # 111 Hz Backbone

# --- Data Points (Scale in meters, Mass in kg) ---
nodes = {
    "Planck Limit": (1e-35, 2.176e-8),
    "Proton": (0.84e-15, 1.672e-27),
    "DNA Helix": (2e-9, 1e-21),
    "Virus": (1e-7, 1e-17),
    "Flea": (1e-3, 1e-5),
    "16\" Pizza Pan": (0.406, 1.0),
    "Human": (1.7, 70),
    "Earth": (6.371e6, 5.972e24),
    "Sun": (6.957e8, 1.989e30),
    "Milky Way": (9.46e20, 1.5e42),
    "Galaxy Cluster": (1e23, 1e45),
    "Observable Universe": (4.4e26, 1e54)
}

# --- Generate Lines ---
# Scale range from Planck to Hubble
r_range = np.logspace(-36, 28, 500)

# 1. Schwarzschild Limit (Gravity Collapse) -> Rs = 2GM/c^2 => M = (R * c^2) / (2 * G)
m_schwarzschild = (r_range * c**2) / (2 * G)

# 2. Compton Limit (Quantum Gravity Limit) -> lambda = h/(mc) => M = h / (R * c)
m_compton = h / (r_range * c)

# 3. 111 Hz Lattice Band -> M = kappa * 111Hz * R (Simplified for visualization)
# This matches the "M_lattice = K * 111Hz * R" formula from the image
m_lattice = (kappa * f_backbone * 10**18) * r_range

# --- Plotting ---
plt.figure(figsize=(14, 10), facecolor='black')
ax = plt.gca()
ax.set_facecolor('black')

# Plot Boundaries
plt.plot(r_range, m_schwarzschild, color='grey', linestyle='--', alpha=0.6, label='Schwarzschild (Gravity)')
plt.plot(r_range, m_compton, color='magenta', linestyle=':', linewidth=2, label='Quantum Gravity Limit (Compton)')
plt.plot(r_range, m_lattice, color='orange', linewidth=3, label='111 Hz Unified Lattice (κ=9.009e-04)')

# Plot Nodes
for name, (r, m) in nodes.items():
    plt.scatter(r, m, color='cyan', s=60, edgecolors='white', zorder=5)
    # Positioning text slightly offset for readability
    plt.text(r * 1.5, m * 1.5, name, color='white', fontsize=9, fontweight='bold', alpha=0.9)

# Formatting
plt.xscale('log')
plt.yscale('log')
plt.xlim(1e-36, 1e28)
plt.ylim(1e-50, 1e70)

# Labels & Titles
plt.xlabel('Scale (Meters, log)', color='orange', fontsize=12)
plt.ylabel('Mass (Kilograms, log)', color='orange', fontsize=12)
plt.title('LatticeLogOS: 111Hz Lattice Unifies Gravity at MICRO (11)\n"When there is no distance there is no time. These are human constructs."',
          color='orange', fontsize=16, pad=20)

# Legend & Grid
leg = plt.legend(facecolor='black', edgecolor='white', loc='upper left')
for text in leg.get_texts():
    text.set_color('white')

plt.grid(True, which="both", ls="-", color='grey', alpha=0.2)
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

# Highlights
plt.annotate('MICRO (11) Node', xy=(1e-35, 1e-8), xytext=(1e-34, 1e1),
             arrowprops=dict(facecolor='lime', shrink=0.05), color='lime', fontweight='bold')
plt.annotate('MACRO (19)★ Star', xy=(4.4e26, 1e54), xytext=(1e20, 1e60),
             arrowprops=dict(facecolor='gold', shrink=0.05), color='gold', fontweight='bold')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_16091/2165761845.py in <cell line: 0>()
# ----> 1 python
#       2 import matplotlib.pyplot as plt
#       3 import numpy as np
#       4
#       5 # --- Constants & Lattice Parameters ---
#
# NameError: name 'python' is not defined

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- Constants & Lattice Parameters ---
G = 6.67430e-11  # Gravitational Constant
c = 299792458    # Speed of Light
h = 6.62607e-34  # Planck Constant
kappa = 9.009e-4 # User Coupling Constant
f_backbone = 111 # 111 Hz Backbone

# --- Data Points (Scale in meters, Mass in kg) ---
nodes = {
    "Planck Limit": (1e-35, 2.176e-8),
    "Proton": (0.84e-15, 1.672e-27),
    "DNA Helix": (2e-9, 1e-21),
    "Virus": (1e-7, 1e-17),
    "Flea": (1e-3, 1e-5),
    "16\" Pizza Pan": (0.406, 1.0),
    "Human": (1.7, 70),
    "Earth": (6.371e6, 5.972e24),
    "Sun": (6.957e8, 1.989e30),
    "Milky Way": (9.46e20, 1.5e42),
    "Galaxy Cluster": (1e23, 1e45),
    "Observable Universe": (4.4e26, 1e54)
}

# --- Generate Lines ---
# Scale range from Planck to Hubble
r_range = np.logspace(-36, 28, 500)

# 1. Schwarzschild Limit (Gravity Collapse) -> Rs = 2GM/c^2 => M = (R * c^2) / (2 * G)
m_schwarzschild = (r_range * c**2) / (2 * G)

# 2. Compton Limit (Quantum Gravity Limit) -> lambda = h/(mc) => M = h / (R * c)
m_compton = h / (r_range * c)

# 3. 111 Hz Lattice Band -> M = kappa * 111Hz * R (Simplified for visualization)
# This matches the "M_lattice = K * 111Hz * R" formula from the image
m_lattice = (kappa * f_backbone * 10**18) * r_range

# --- Plotting ---
plt.figure(figsize=(14, 10), facecolor='black')
ax = plt.gca()
ax.set_facecolor('black')

# Plot Boundaries
plt.plot(r_range, m_schwarzschild, color='grey', linestyle='--', alpha=0.6, label='Schwarzschild (Gravity)')
plt.plot(r_range, m_compton, color='magenta', linestyle=':', linewidth=2, label='Quantum Gravity Limit (Compton)')
plt.plot(r_range, m_lattice, color='orange', linewidth=3, label='111 Hz Unified Lattice (κ=9.009e-04)')

# Plot Nodes
for name, (r, m) in nodes.items():
    plt.scatter(r, m, color='cyan', s=60, edgecolors='white', zorder=5)
    # Positioning text slightly offset for readability
    plt.text(r * 1.5, m * 1.5, name, color='white', fontsize=9, fontweight='bold', alpha=0.9)

# Formatting
plt.xscale('log')
plt.yscale('log')
plt.xlim(1e-36, 1e28)
plt.ylim(1e-50, 1e70)

# Labels & Titles
plt.xlabel('Scale (Meters, log)', color='orange', fontsize=12)
plt.ylabel('Mass (Kilograms, log)', color='orange', fontsize=12)
plt.title('LatticeLogOS: 111Hz Lattice Unifies Gravity at MICRO (11)\n"When there is no distance there is no time. These are human constructs."',
          color='orange', fontsize=16, pad=20)

# Legend & Grid
leg = plt.legend(facecolor='black', edgecolor='white', loc='upper left')
for text in leg.get_texts():
    text.set_color('white')

plt.grid(True, which="both", ls="-", color='grey', alpha=0.2)
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

# Highlights
plt.annotate('MICRO (11) Node', xy=(1e-35, 1e-8), xytext=(1e-34, 1e1),
             arrowprops=dict(facecolor='lime', shrink=0.05), color='lime', fontweight='bold')
plt.annotate('MACRO (19)★ Star', xy=(4.4e26, 1e54), xytext=(1e20, 1e60),
             arrowprops=dict(facecolor='gold', shrink=0.05), color='gold', fontweight='bold')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- Constants & Lattice Parameters ---
G = 6.67430e-11  # Gravitational Constant
c = 299792458    # Speed of Light
h = 6.62607e-34  # Planck Constant
kappa = 9.009e-4 # User Coupling Constant
f_backbone = 111 # 111 Hz Backbone

# --- Data Points (Scale in meters, Mass in kg) ---
nodes = {
    "Planck Limit": (1e-35, 2.176e-8),
    "Proton": (0.84e-15, 1.672e-27),
    "DNA Helix": (2e-9, 1e-21),
    "Virus": (1e-7, 1e-17),
    "Flea": (1e-3, 1e-5),
    "16\" Pizza Pan": (0.406, 1.0),
    "Human": (1.7, 70),
    "Earth": (6.371e6, 5.972e24),
    "Sun": (6.957e8, 1.989e30),
    "Milky Way": (9.46e20, 1.5e42),
    "Galaxy Cluster": (1e23, 1e45),
    "Observable Universe": (4.4e26, 1e54)
}

# --- Generate Lines ---
r_range = np.logspace(-36, 28, 500)
m_schwarzschild = (r_range * c**2) / (2 * G)
m_compton = h / (r_range * c)
m_lattice = (kappa * f_backbone * 10**18) * r_range

# --- Plotting ---
# Height increased to 12 to ensure the footer has plenty of breathing room
fig = plt.figure(figsize=(14, 12), facecolor='black')
ax = plt.gca()
ax.set_facecolor('black')

# Plot Boundaries
plt.plot(r_range, m_schwarzschild, color='grey', linestyle='--', alpha=0.6, label='Schwarzschild (Gravity)')
plt.plot(r_range, m_compton, color='magenta', linestyle=':', linewidth=2, label='Quantum Gravity Limit (Compton)')
plt.plot(r_range, m_lattice, color='orange', linewidth=3, label='111 Hz Unified Lattice (κ=9.009e-04)')

# Plot Nodes
for name, (r, m) in nodes.items():
    plt.scatter(r, m, color='cyan', s=60, edgecolors='white', zorder=5)
    plt.text(r * 1.5, m * 1.5, name, color='white', fontsize=9, fontweight='bold', alpha=0.9)

# Formatting
plt.xscale('log')
plt.yscale('log')
plt.xlim(1e-36, 1e28)
plt.ylim(1e-50, 1e70)

# Labels & Titles
plt.xlabel('Scale (Meters, log)', color='orange', fontsize=12)
plt.ylabel('Mass (Kilograms, log)', color='orange', fontsize=12)
plt.title('LatticeLogOS: 111Hz Lattice Unifies Gravity at MICRO (11)\n"When there is no distance there is no time. These are human constructs."',
          color='orange', fontsize=16, pad=20)

# --- THE REQUESTED FOOTER ---
# Using a slightly larger font and brighter white for the quote
footer_text = ("*“This chart places all four fundamental forces and many known scales — from the Planck limit to the Hubble Horizon — along a single 111 Hz lattice band.\n"
               "It does not claim to replace standard cosmology; it proposes a resonant, hexagonal way of seeing the universe’s structure.”")

plt.figtext(0.5, 0.04, footer_text, ha="center", fontsize=11, color="white",
            style='italic', alpha=1.0,
            bbox={"facecolor":"#0A0A0A", "alpha":0.8, "pad":10, "edgecolor":"orange", "lw":1.5})

# Legend & Grid
leg = plt.legend(facecolor='black', edgecolor='white', loc='upper left')
for text in leg.get_texts():
    text.set_color('white')

plt.grid(True, which="both", ls="-", color='grey', alpha=0.2)
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

# Highlights
plt.annotate('MICRO (11) Node', xy=(1e-35, 1e-8), xytext=(1e-34, 1e1),
             arrowprops=dict(facecolor='lime', shrink=0.05), color='lime', fontweight='bold')
plt.annotate('MACRO (19)★ Star', xy=(4.4e26, 1e54), xytext=(1e20, 1e60),
             arrowprops=dict(facecolor='gold', shrink=0.05), color='gold', fontweight='bold')

plt.subplots_adjust(bottom=0.2) # Increased margin to prevent overlapping the X-axis label
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# LatticeLogOS Parameters
n_shells = np.arange(1, 21) # Shells 1 through 20
kappa = 9.009e-4
f_backbone = 111

# Calculate Gnomon Complexity (H(n) = 3n^2 - 3n + 1)
gnomon_units = 3*n_shells**2 - 3*n_shells + 1
cumulative_volume = n_shells**3

# Plotting the Pulse-Phase Map
plt.figure(figsize=(12, 8), facecolor='black')
ax = plt.gca()
ax.set_facecolor('black')

# Plot the Staircase Growth (Volume Accretion)
plt.step(n_shells, cumulative_volume, where='post', color='lime', linewidth=3, label='n³ Volume Accretion')

# Highlight the "Impossible" z > 11 Shell
plt.scatter(19, 19**3, color='gold', s=200, zorder=5, label='MACRO(19)★ Shell Tick')
plt.annotate('Hubble Horizon\nSystem Lock', xy=(19, 19**3), xytext=(12, 7000),
             arrowprops=dict(facecolor='gold', shrink=0.05), color='gold', fontweight='bold')

# Formatting
plt.title('LatticeLogOS: Pulse-Phase Map\n"The Universe Assembles Itself Shell by Shell"', color='lime', fontsize=16)
plt.xlabel('Gnomon Shell Number (n)', color='lime')
plt.ylabel('Total Lattice Units (n³)', color='lime')
plt.grid(color='grey', alpha=0.3)
ax.tick_params(colors='white')

# Add the 111 Hz Frequency Marker
for n in n_shells:
    plt.text(n, n**3, f'{f_backbone}Hz', color='white', fontsize=8, alpha=0.6)

plt.legend(facecolor='black', labelcolor='white')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# LatticeLogOS Parameters
n_shells = np.arange(1, 21) # Shells 1 through 20
kappa = 9.009e-4
f_backbone = 111

# Calculate Gnomon Complexity (H(n) = 3n^2 - 3n + 1)
gnomon_units = 3*n_shells**2 - 3*n_shells + 1
cumulative_volume = n_shells**3

# Plotting the Pulse-Phase Map
# Increased height (11) to provide room for the footer
fig = plt.figure(figsize=(12, 11), facecolor='black')
ax = plt.gca()
ax.set_facecolor('black')

# Plot the Staircase Growth (Volume Accretion)
plt.step(n_shells, cumulative_volume, where='post', color='lime', linewidth=3, label='n³ Volume Accretion')

# Highlight the "Impossible" z > 11 Shell
plt.scatter(19, 19**3, color='gold', s=200, zorder=5, label='MACRO(19)★ Shell Tick')
plt.annotate('Hubble Horizon\nSystem Lock', xy=(19, 19**3), xytext=(12, 7000),
             arrowprops=dict(facecolor='gold', shrink=0.05), color='gold', fontweight='bold')

# Formatting
plt.title('LatticeLogOS: Pulse-Phase Map\n"The Universe Assembles Itself Shell by Shell"', color='lime', fontsize=16)
plt.xlabel('Gnomon Shell Number (n)', color='lime', fontsize=12)
plt.ylabel('Total Lattice Units (n³)', color='lime', fontsize=12)
plt.grid(color='grey', alpha=0.3)
ax.tick_params(colors='white')

# Add the 111 Hz Frequency Marker
for n in n_shells:
    plt.text(n, n**3, f'{f_backbone}Hz', color='white', fontsize=8, alpha=0.6)

# --- REFINED FOOTER ---
footer_text = ("*“This chart shows how the universe might grow in discrete shells, like a 3D lattice printer, using the 100 Pillars as real‑world examples.\n"
               "It is presented as a speculative but testable growth forecast, not a final proof of cosmic history.”")

plt.figtext(0.5, 0.05, footer_text, ha="center", fontsize=11, color="white",
            style='italic', alpha=1.0,
            bbox={"facecolor":"#0A0A0A", "alpha":0.8, "pad":10, "edgecolor":"lime", "lw":1.5})

plt.legend(facecolor='black', labelcolor='white', loc='upper left')

# Adjust layout to prevent the footer from overlapping the X-axis
plt.subplots_adjust(bottom=0.22)

plt.show()
