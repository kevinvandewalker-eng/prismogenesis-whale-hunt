# %% [markdown]
# <a href="https://colab.research.google.com/github/kevinvandewalker-eng/prismogenesis-whale-hunt/blob/main/Interactive_LatticeLogOS_GUT_Chart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import plotly.graph_objects as go
import numpy as np

# Constants
G, c, h = 6.674e-11, 3.0e8, 6.626e-34

fig = go.Figure()

# 1. Physics Boundaries (Schwarzschild & Compton)
r_grid = np.logspace(-45, 35, 500)
schwarz = (c**2 * r_grid) / (2*G)
compton = h / (r_grid * c)

fig.add_trace(go.Scatter(x=r_grid, y=schwarz, name="Schwarzschild Limit", line=dict(color='white', dash='dash')))
fig.add_trace(go.Scatter(x=r_grid, y=compton, name="Compton Boundary", line=dict(color='#ff00ff', dash='dot')))

# 2. LatticeLog LE Sync Line
sync_r = np.logspace(-35, 26.6, 300)
sync_m = (10**22.5 * sync_r) * (1 + (sync_r/1e10)**1.25)
fig.add_trace(go.Scatter(x=sync_r, y=sync_m, name="LatticeLog LE Sync", line=dict(color='#ff3300', width=4)))

# 3. Celestial Objects (Cyan)
objects = {
    "Atoms": (1e-10, 1e-26), "Planets": (1e7, 1e25), "Stars": (1e9, 1e30),
    "Galaxies": (1e21, 1e42), "Clusters": (1e23, 1e45)
}
for name, (r, m) in objects.items():
    fig.add_trace(go.Scatter(
        x=[r], y=[m], name=name, mode='markers+text',
        text=[name], textposition="top center",
        marker=dict(color='#00ffff', size=15, line=dict(width=2, color='black'))
    ))

# 4. Lever Points (Yellow) + Gold Star
levers = {
    "MICRO (11)": (1.6e-35, 2.2e-8), "FLEA (30)": (1e-3, 1e-5),
    "LUNGS": (1, 70), "MACRO (19)": (4.4e26, 1e54)
}
for name, (r, m) in levers.items():
    fig.add_trace(go.Scatter(
        x=[r], y=[m], name=name, mode='markers+text',
        text=[name], textposition="top right",
        marker=dict(color='#ffff00', size=20, symbol='diamond', line=dict(width=2, color='white'))
    ))

# The Universe Gold Star
fig.add_trace(go.Scatter(
    x=[4.4e26], y=[1e54], name="The Universe", mode='markers',
    marker=dict(color='gold', size=40, symbol='star', line=dict(width=3, color='black'))
))

# 5. Layout and Styling
fig.update_layout(
    title="LatticeLogOS Grand Unification: Quantum → Cosmic",
    template="plotly_dark",
    xaxis_type="log", yaxis_type="log",
    xaxis=dict(title="Scale (Meters)", range=[-42, 34], gridcolor='rgba(255,255,255,0.05)'),
    yaxis=dict(title="Mass (Kilograms)", range=[-48, 105], gridcolor='rgba(255,255,255,0.05)'),
# Out:
#   File "/tmp/ipykernel_530/2561378367.py", line 58
#     yaxis=dict(title="Mass (Kilograms)", range=[-48, 105], gridcolor='rgba(255,255,255,0.05)'),
#                                                                                                ^
# SyntaxError: incomplete input

# %%
import plotly.graph_objects as go
import numpy as np

# Constants
G, c, h = 6.674e-11, 3.0e8, 6.626e-34
date_stamp = "March 30, 2026"

fig = go.Figure()

# 1. Physics Boundaries (Schwarzschild & Compton)
r_grid = np.logspace(-45, 35, 500)
schwarz = (c**2 * r_grid) / (2*G)
compton = h / (r_grid * c)

# Schwarzschild Limit
fig.add_trace(go.Scatter(
    x=r_grid, y=schwarz, name="SCHWARZSCHILD LIMIT",
    line=dict(color='white', width=2, dash='dash'),
    hoverinfo='name'
))

# Compton Boundary
fig.add_trace(go.Scatter(
    x=r_grid, y=compton, name="COMPTON BOUNDARY",
    line=dict(color='#ff00ff', width=2, dash='dot'),
    hoverinfo='name'
))

# 2. LatticeLog LE Sync Line
sync_r = np.logspace(-35, 26.6, 300)
sync_m = (10**22.5 * sync_r) * (1 + (sync_r/1e10)**1.25)
fig.add_trace(go.Scatter(
    x=sync_r, y=sync_m, name="LatticeLog LE Sync",
    line=dict(color='#ff3300', width=6),
    hoverinfo='name'
))

# 3. Celestial Objects (Cyan)
objects = {
    "Atoms": (1e-10, 1e-26), "Planets": (1e7, 1e25), "Stars": (1e9, 1e30),
    "Galaxies": (1e21, 1e42), "Clusters": (1e23, 1e45)
}

obj_x = [v[0] for v in objects.values()]
obj_y = [v[1] for v in objects.values()]
obj_labels = list(objects.keys())

fig.add_trace(go.Scatter(
    x=obj_x, y=obj_y, mode='markers+text',
    name="Cosmic Objects",
    text=obj_labels,
    textposition="top center",
    marker=dict(color='#00ffff', size=12, line=dict(width=1, color='black')),
    textfont=dict(color='#00ffff', size=14)
))

# 4. Lever Points (Yellow)
levers = {
    "MICRO (11)": (1.6e-35, 2.2e-8), "FLEA (30)": (1e-3, 1e-5),
    "LUNGS": (1, 70), "MACRO (19)": (4.4e26, 1e54)
}

lev_x = [v[0] for v in levers.values()]
lev_y = [v[1] for v in levers.values()]
lev_labels = list(levers.keys())

fig.add_trace(go.Scatter(
    x=lev_x, y=lev_y, mode='markers+text',
    name="Lever Points",
    text=lev_labels,
    textposition="top right",
    marker=dict(color='#ffff00', size=18, symbol='diamond', line=dict(width=2, color='white')),
    textfont=dict(color='#ffff00', size=16)
))

# 5. Universe Gold Star
fig.add_trace(go.Scatter(
    x=[4.4e26], y=[1e54], mode='markers',
    name="THE UNIVERSE",
    marker=dict(color='gold', size=45, symbol='star', line=dict(width=3, color='black')),
    hovertext="Grand Unification Point",
    hoverinfo="text+name"
))

# Layout Styling
fig.update_layout(
    title=dict(
        text=f"LatticeLogOS Grand Unification Chart<br><sup>Buckley Wa • Twisted Physics™ | {date_stamp}</sup>",
        font=dict(size=24, color='gold')
    ),
    template="plotly_dark",
    xaxis_type="log", yaxis_type="log",
    xaxis=dict(title="Scale (Meters)", range=[-42, 34], showgrid=True, gridcolor='rgba(255,255,255,0.05)'),
    yaxis=dict(title="Mass (Kilograms)", range=[-48, 105], showgrid=True, gridcolor='rgba(255,255,255,0.05)'),
    showlegend=True,
    width=1100, height=800,
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="61543d36-b63e-43fe-87ef-fa30b3a7f786" class="plotly-graph-div" style="height:800px; width:1100px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("
# %%
import plotly.graph_objects as go
import numpy as np

# Constants
G, c, h = 6.674e-11, 3.0e8, 6.626e-34
date_stamp = "March 30, 2026"

fig = go.Figure()

# 1. Physics Boundaries (Log-Log Scale)
r_grid = np.logspace(-45, 35, 500)
schwarz = (c**2 * r_grid) / (2*G)
compton = h / (r_grid * c)

fig.add_trace(go.Scatter(x=r_grid, y=schwarz, name="SCHWARZSCHILD LIMIT",
                         line=dict(color='white', width=2, dash='dash'), hoverinfo='name'))
fig.add_trace(go.Scatter(x=r_grid, y=compton, name="COMPTON BOUNDARY",
                         line=dict(color='#ff00ff', width=2, dash='dot'), hoverinfo='name'))

# 2. LatticeLog LE Sync Line
sync_r = np.logspace(-35, 26.6, 300)
sync_m = (10**22.5 * sync_r) * (1 + (sync_r/1e10)**1.25)
fig.add_trace(go.Scatter(x=sync_r, y=sync_m, name="LatticeLog LE Sync",
                         line=dict(color='#ff3300', width=6), hoverinfo='name'))

# 3. Celestial Objects (Cyan)
objects = {
    "Atoms": (1e-10, 1e-26), "Planets": (1e7, 1e25), "Stars": (1e9, 1e30),
    "Galaxies": (1e21, 1e42), "Clusters": (1e23, 1e45)
}

for name, (r, m) in objects.items():
    fig.add_trace(go.Scatter(x=[r], y=[m], mode='markers', name=name,
                             marker=dict(color='#00ffff', size=12, line=dict(width=1, color='black'))))
    # Staggered annotations to prevent text-on-icon overlap
    fig.add_annotation(x=np.log10(r), y=np.log10(m), text=name, showarrow=False,
                       xshift=-35 if "Galaxies" in name or "Planets" in name else 35,
                       yshift=15, font=dict(color="#00ffff", size=14), xref="x", yref="y")

# 4. Lever Points (Yellow) - PIXEL-PERFECT OFFSETS
levers = {
    "MICRO (11)": (1.6e-35, 2.2e-8), "FLEA (30)": (1e-3, 1e-5),
    "LUNGS": (1, 70), "MACRO (19)": (4.4e26, 1e54)
}

for name, (r, m) in levers.items():
    fig.add_trace(go.Scatter(x=[r], y=[m], mode='markers', name=name,
                             marker=dict(color='#ffff00', size=20, symbol='diamond',
                             line=dict(width=2, color='white'))))

    # Logic to push text away from the center of the diamond icon
    x_off = -50 if "FLEA" in name else (50 if "LUNGS" in name else 0)
    y_off = 35 if "MACRO" in name or "MICRO" in name else 0

    fig.add_annotation(x=np.log10(r), y=np.log10(m), text=f"<b>{name}</b>", showarrow=False,
                       xshift=x_off, yshift=y_off,
                       font=dict(color="#ffff00", size=16),
                       bgcolor="rgba(0,0,0,0.6)", bordercolor="white", borderpad=4,
                       xref="x", yref="y")

# 5. Universe Gold Star
fig.add_trace(go.Scatter(x=[4.4e26], y=[1e54], mode='markers', name="THE UNIVERSE",
752771174629379e-30,1.7000469752067145e-30,2.4591304254680515e-30,3.5571502068213824e-30,5.145443878390904e-30,7.442922330043758e-30,1.0766241770454888e-29,1.5573447729261353e-29,2.2527106426459734e-29,3.25856247615323e-29,4.7135345347868973e-29,6.818162294944494e-29,9.862521794868765e-29,1.4266210152607297e-28,2.0636177678638565e-28,2.985038245118717e-28,4.317879727332022e-28,6.245844712439592e-28,9.034660211810535e-28,1.3068702297433422e-27,1.8903973778192235e-27,2.734473679737574e-27,3.955436244734709e-27,5.72156755506324e-27,8.276289456246302e-27,1.1971713434189656e-26,1.731717133723346e-26,2.5049415421745024e-26,3.623416323323135e-26,5.241298302206062e-26,7.581576457522087e-26,1.0966805983368697e-25,1.5863565335085864e-25,2.294676367231941e-25,3.319266204733183e-25,4.801342923653425e-25,6.945177773823689e-25,1.0046250617173362e-24,1.4531975242368955e-24,2.10206088313015e-24,3.0406464934670687e-24,4.398317466650211e-24,6.3621984926574955e-24,9.202966808760391e-24,1.3312159025043104e-23,1.9256135721291946e-23,2.785414163241752e-23,4.0291220279513437e-23,5.828154581230815e-23,8.430468371788967e-23,1.2194734366967332e-22,1.7639772753140452e-22,2.551606073727176e-22,3.690916910662782e-22,5.338938397147339e-22,7.722813571 ...

# %%
import plotly.graph_objects as go
import numpy as np

# Constants
G, c, h = 6.674e-11, 3.0e8, 6.626e-34
date_stamp = "March 30, 2026"

fig = go.Figure()

# 1. Boundaries
r_grid = np.logspace(-45, 35, 500)
schwarz = (c**2 * r_grid) / (2*G)
compton = h / (r_grid * c)

fig.add_trace(go.Scatter(x=r_grid, y=schwarz, name="SCHWARZSCHILD LIMIT",
                         line=dict(color='white', width=2, dash='dash')))
fig.add_trace(go.Scatter(x=r_grid, y=compton, name="COMPTON BOUNDARY",
                         line=dict(color='#ff00ff', width=2, dash='dot')))

# 2. Sync Line
sync_r = np.logspace(-35, 26.6, 300)
sync_m = (10**22.5 * sync_r) * (1 + (sync_r/1e10)**1.25)
fig.add_trace(go.Scatter(x=sync_r, y=sync_m, name="LatticeLog LE Sync",
                         line=dict(color='#ff3300', width=5)))

# 3. Objects & Levers (Combined for clean labeling)
points = {
    "Atoms": (1e-10, 1e-26, "#00ffff", "top center"),
    "Planets": (1e7, 1e25, "#00ffff", "middle left"),
    "Stars": (1e9, 1e30, "#00ffff", "middle right"),
    "Galaxies": (1e21, 1e42, "#00ffff", "middle left"),
    "Clusters": (1e23, 1e45, "#00ffff", "middle right"),
    "MICRO (11)": (1.6e-35, 2.2e-8, "#ffff00", "top center"),
    "FLEA (30)": (1e-3, 1e-5, "#ffff00", "middle left"), # Shifted Left
    "LUNGS": (1, 70, "#ffff00", "middle right"),        # Shifted Right
    "MACRO (19)": (4.4e26, 1e54, "#ffff00", "top center")
}

for name, (r, m, color, pos) in points.items():
    fig.add_trace(go.Scatter(
        x=[r], y=[m], name=name, mode='markers+text',
        text=[f"<b>{name}</b>"], textposition=pos,
        marker=dict(color=color, size=12 if color=="#00ffff" else 18,
                    symbol='circle' if color=="#00ffff" else 'diamond'),
        textfont=dict(color=color, size=14)
    ))

# 4. Universe Gold Star
fig.add_trace(go.Scatter(
    x=[4.4e26], y=[1e54], name="THE UNIVERSE", mode='markers',
    marker=dict(color='gold', size=40, symbol='star', line=dict(width=2, color='black'))
))

# 5. Layout - FIXES FOR COLAB VISIBILITY
fig.update_layout(
    title=dict(text=f"LatticeLogOS Grand Unification Chart<br><sup>{date_stamp}</sup>",
               x=0.5, font=dict(size=22, color='gold')),
    template="plotly_dark",
    xaxis_type="log", yaxis_type="log",
    xaxis=dict(title="Scale (Meters)", range=[-42, 34]),
    yaxis=dict(title="Mass (Kilograms)", range=[-48, 105]),

    # LEGEND FIX: Moves key to bottom to avoid being cut off
    legend=dict(
        orientation="h",
        yanchor="bottom",
        y=-0.2,
        xanchor="center",
        x=0.5,
        font=dict(size=12)
    ),

    # MARGIN FIX: Adds padding so labels aren't clipped
    margin=dict(l=60, r=60, t=100, b=150),
    width=1000,
    height=800
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="218f2b44-b2dd-4062-9371-1afdd8f75580" class="plotly-graph-div" style="height:800px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("218f2b44-b2dd-4062-9371-1afdd8f75580")) {                    Plotly.newPlot(                        "218f2b44-b2dd-4062-9371-1afdd8f75580",                        [{"line":{"color":"white","dash":"dash","width":2},"name":"SCHWARZSCHILD LIMIT","x":[1e-45,1.446507338521653e-45,2.092383480396962e-45,3.026648059395683e-45,4.378068629038175e-45,6.332908400455153e-45,9.160598475443653e-45,1.3250872919979512e-44,1.9167484920568208e-44,2.7725907598605037e-44,4.0105728808554796e-44,5.801323103833378e-44,8.391656442830196e-44,1.213859262690619e-43,1.7558563314144633e-43,2.5398590687807293e-43,3.673924781802097e-43,5.3143591580532085e-43,7.68725952166372e-43,1.1119677311207024e-42,1.608469483265342e-42,2.3266629113314484e-42,3.3655349755070943e-42,4.868271040122304e-42,7.041989785449239e-42,1.0186289902446845e-41,1.4734543096198372e-41,2.1313624718414507e-41,3.083031456568258e-41,4.4596276268190867e-41,6.450884089267712e-41,9.331251175078317e-41,1.3497723302339362e-40,1.952455581016861e-40,2.824241326078447e-40,4.085285803928532e-40,5.909395895340952e-40,8.547984528840422e-40,1.2364722350537225e-39,1.788566161883451e-39,2.5871740785959186e-39,3.7423662907219924e-39,5.413360302965331e-39,7.830465404301151e-39,1.1326825671361537e-38,1.6384336455779914e-38,2.370006292009311e-38,3.42823149373396e-38,4.958962013837222e-38,7.173174944465657e-38,1.0376050197669053e-37,1.5009032755797334e-37,2.1710676025372717e-37,3.140465219496775e-37,4.542705986374024e-37,6.57105754603627e-37,9.50508296218955e-37,1.3749172258064092e-36,1.9888278569888036e-36,2.8768540901905974e-36,4.1613905533167327e-36,6.019481973827238e-36,8.707224849239904e-36,1.2595064642583614e-35,1.8218853434651502e-35,2.6353705192673823e-35,3.812082795843888e-35,5.514205739240325e-35,7.976339067929346e-35,1.1537832996296573e-34,1.6689560099780266e-34,2.414157116102993e-34,3.49209598478725e-34,5.051342468816756e-34,7.306803950529522e-34,1.056934553557996e-33,1.5288635880587232e-33,2.2115123997254887e-33,3.198968915434551e-33,4.6273320118786554e-33,6.69346971295864e-33,9.682153059967096e-33,1.4005305453932168e-32,2.0258777117350048e-32,2.9304469769721385e-32,4.238913057338792e-32,6.131618844795769e-32,8.869431656014668e-32,1.2829697978941475e-31,1.8558252277555264e-31,2.6844648109619652e-31,3.8830980490595933e-31,5.616929824163816e-31,8.124930210614031e-31,1.1752771174629379e-30,1.7000469752067145e-30,2.4591304254680515e-30,3.5571502068213824e-30,5.145443878390904e-30,7.442922330043758e-30,1.0766241770454888e-29,1.5573447729261353e-29,2.2527106426459734e-29,3.25856247615323e-29,4.7135345347868973e-29,6.818162294944494e-29,9.862521794868765e-29,1.4266210152607297e-28,2.0636177678638565e-28,2.985038245118717e-28,4.317879727332022e-28,6.245844712439592e-28,9.034660211810535e-28,1.3068702297433422e-27,1.8903973778192235e-27,2.734473679737574e-27,3.955436244734709e-27,5.72156755506324e-27,8.276289456246302e-27,1.1971713434189656e-26,1.731717133723346e-26,2.5049415421745024e-26,3.623416323323135e-26,5.241298302206062e-26,7.581576457522087e-26,1.0966805983368697e-25,1.5863565335085864e-25,2.294676367231941e-25,3.319266204733183e-25,4.801342923653425e-25,6.945177773823689e-25,1.0046250617173362e-24,1.4531975242368955e-24,2.10206088313015e-24,3.0406464934670687e-24,4.398317466650211e-24,6.3621984926574955e-24,9.202966808760391e-24,1.3312159025043104e-23,1.9256135721291946e-23,2.785414163241752e-23,4.0291220279513437e-23,5.828154581230815e-23,8.430468371788967e-23,1.2194734366967332e-22,1.7639772753140452e-22,2.551606073727176e-22,3.690916910662782e-22,5.338938397147339e-22,7.722813571388659e-22,1.117110 ...

# %%
import plotly.graph_objects as go
import numpy as np

# Constants
G, c, h = 6.674e-11, 3.0e8, 6.626e-34
date_stamp = "March 30, 2026"

fig = go.Figure()

# 1. Physics Boundaries
r_grid = np.logspace(-45, 35, 500)
schwarz = (c**2 * r_grid) / (2*G)
compton = h / (r_grid * c)

fig.add_trace(go.Scatter(x=r_grid, y=schwarz, name="SCHWARZSCHILD LIMIT",
                         line=dict(color='white', width=2, dash='dash')))
fig.add_trace(go.Scatter(x=r_grid, y=compton, name="COMPTON BOUNDARY",
                         line=dict(color='#ff00ff', width=2, dash='dot')))

# 2. LatticeLog LE Sync Line
sync_r = np.logspace(-35, 26.6, 300)
sync_m = (10**22.5 * sync_r) * (1 + (sync_r/1e10)**1.25)
fig.add_trace(go.Scatter(x=sync_r, y=sync_m, name="LatticeLog LE Sync",
                         line=dict(color='#ff3300', width=5)))

# 3. Objects & Levers (Staggered Labels)
points = {
    "Atoms": (1e-10, 1e-26, "#00ffff", "top center"),
    "Planets": (1e7, 1e25, "#00ffff", "middle left"),
    "Stars": (1e9, 1e30, "#00ffff", "middle right"),
    "Galaxies": (1e21, 1e42, "#00ffff", "middle left"),
    "Clusters": (1e23, 1e45, "#00ffff", "middle right"),
    "MICRO (11)": (1.6e-35, 2.2e-8, "#ffff00", "top center"),
    "FLEA (30)": (1e-3, 1e-5, "#ffff00", "middle left"),
    "LUNGS": (1, 70, "#ffff00", "middle right"),
    "MACRO (19)": (4.4e26, 1e54, "#ffff00", "top center")
}

for name, (r, m, color, pos) in points.items():
    fig.add_trace(go.Scatter(
        x=[r], y=[m], name=name, mode='markers+text',
        text=[f"<b>{name}</b>"], textposition=pos,
        marker=dict(color=color, size=12 if color=="#00ffff" else 18,
                    symbol='circle' if color=="#00ffff" else 'diamond'),
        textfont=dict(color=color, size=14)
    ))

# 4. Universe Gold Star
fig.add_trace(go.Scatter(
    x=[4.4e26], y=[1e54], name="THE UNIVERSE", mode='markers',
    marker=dict(color='gold', size=40, symbol='star', line=dict(width=2, color='black'))
))

# 5. Layout with Deep Legend Buffer
fig.update_layout(
    title=dict(text=f"LatticeLogOS Grand Unification Chart<br><sup>{date_stamp}</sup>",
               x=0.5, font=dict(size=22, color='gold')),
    template="plotly_dark",
    xaxis_type="log", yaxis_type="log",
    xaxis=dict(title="Scale (Meters)", range=[-42, 34]),
    yaxis=dict(title="Mass (Kilograms)", range=[-48, 105]),

    # LEGEND FIX: Moved lower (y=-0.3) and anchored to top
    legend=dict(
        orientation="h",
        yanchor="top",
        y=-0.25,
        xanchor="center",
        x=0.5,
        font=dict(size=12),
        bgcolor="rgba(0,0,0,0)" # Transparent background
    ),

    # MARGIN FIX: Extra bottom padding (b=200) for the legend
    margin=dict(l=60, r=60, t=100, b=220),
    width=1000,
    height=900 # Increased height for the extra legend room
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5c40e25f-f6d2-465d-b531-f82d5ecd2c0b" class="plotly-graph-div" style="height:900px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5c40e25f-f6d2-465d-b531-f82d5ecd2c0b")) {                    Plotly.newPlot(                        "5c40e25f-f6d2-465d-b531-f82d5ecd2c0b",                        [{"line":{"color":"white","dash":"dash","width":2},"name":"SCHWARZSCHILD LIMIT","x":[1e-45,1.446507338521653e-45,2.092383480396962e-45,3.026648059395683e-45,4.378068629038175e-45,6.332908400455153e-45,9.160598475443653e-45,1.3250872919979512e-44,1.9167484920568208e-44,2.7725907598605037e-44,4.0105728808554796e-44,5.801323103833378e-44,8.391656442830196e-44,1.213859262690619e-43,1.7558563314144633e-43,2.5398590687807293e-43,3.673924781802097e-43,5.3143591580532085e-43,7.68725952166372e-43,1.1119677311207024e-42,1.608469483265342e-42,2.3266629113314484e-42,3.3655349755070943e-42,4.868271040122304e-42,7.041989785449239e-42,1.0186289902446845e-41,1.4734543096198372e-41,2.1313624718414507e-41,3.083031456568258e-41,4.4596276268190867e-41,6.450884089267712e-41,9.331251175078317e-41,1.3497723302339362e-40,1.952455581016861e-40,2.824241326078447e-40,4.085285803928532e-40,5.909395895340952e-40,8.547984528840422e-40,1.2364722350537225e-39,1.788566161883451e-39,2.5871740785959186e-39,3.7423662907219924e-39,5.413360302965331e-39,7.830465404301151e-39,1.1326825671361537e-38,1.6384336455779914e-38,2.370006292009311e-38,3.42823149373396e-38,4.958962013837222e-38,7.173174944465657e-38,1.0376050197669053e-37,1.5009032755797334e-37,2.1710676025372717e-37,3.140465219496775e-37,4.542705986374024e-37,6.57105754603627e-37,9.50508296218955e-37,1.3749172258064092e-36,1.9888278569888036e-36,2.8768540901905974e-36,4.1613905533167327e-36,6.019481973827238e-36,8.707224849239904e-36,1.2595064642583614e-35,1.8218853434651502e-35,2.6353705192673823e-35,3.812082795843888e-35,5.514205739240325e-35,7.976339067929346e-35,1.1537832996296573e-34,1.6689560099780266e-34,2.414157116102993e-34,3.49209598478725e-34,5.051342468816756e-34,7.306803950529522e-34,1.056934553557996e-33,1.5288635880587232e-33,2.2115123997254887e-33,3.198968915434551e-33,4.6273320118786554e-33,6.69346971295864e-33,9.682153059967096e-33,1.4005305453932168e-32,2.0258777117350048e-32,2.9304469769721385e-32,4.238913057338792e-32,6.131618844795769e-32,8.869431656014668e-32,1.2829697978941475e-31,1.8558252277555264e-31,2.6844648109619652e-31,3.8830980490595933e-31,5.616929824163816e-31,8.124930210614031e-31,1.1752771174629379e-30,1.7000469752067145e-30,2.4591304254680515e-30,3.5571502068213824e-30,5.145443878390904e-30,7.442922330043758e-30,1.0766241770454888e-29,1.5573447729261353e-29,2.2527106426459734e-29,3.25856247615323e-29,4.7135345347868973e-29,6.818162294944494e-29,9.862521794868765e-29,1.4266210152607297e-28,2.0636177678638565e-28,2.985038245118717e-28,4.317879727332022e-28,6.245844712439592e-28,9.034660211810535e-28,1.3068702297433422e-27,1.8903973778192235e-27,2.734473679737574e-27,3.955436244734709e-27,5.72156755506324e-27,8.276289456246302e-27,1.1971713434189656e-26,1.731717133723346e-26,2.5049415421745024e-26,3.623416323323135e-26,5.241298302206062e-26,7.581576457522087e-26,1.0966805983368697e-25,1.5863565335085864e-25,2.294676367231941e-25,3.319266204733183e-25,4.801342923653425e-25,6.945177773823689e-25,1.0046250617173362e-24,1.4531975242368955e-24,2.10206088313015e-24,3.0406464934670687e-24,4.398317466650211e-24,6.3621984926574955e-24,9.202966808760391e-24,1.3312159025043104e-23,1.9256135721291946e-23,2.785414163241752e-23,4.0291220279513437e-23,5.828154581230815e-23,8.430468371788967e-23,1.2194734366967332e-22,1.7639772753140452e-22,2.551606073727176e-22,3.690916910662782e-22,5.338938397147339e-22,7.722813571388659e-22,1.117110 ...

# %%
import plotly.graph_objects as go
import numpy as np

# Constants
G, c, h = 6.674e-11, 3.0e8, 6.626e-34
date_stamp = "March 30, 2026"

fig = go.Figure()

# 1. Physics Boundaries
r_grid = np.logspace(-45, 35, 500)
schwarz = (c**2 * r_grid) / (2*G)
compton = h / (r_grid * c)

fig.add_trace(go.Scatter(x=r_grid, y=schwarz, name="SCHWARZSCHILD LIMIT",
                         line=dict(color='white', width=2, dash='dash')))
fig.add_trace(go.Scatter(x=r_grid, y=compton, name="COMPTON BOUNDARY",
                         line=dict(color='#ff00ff', width=2, dash='dot')))

# 2. LatticeLog LE Sync Line
sync_r = np.logspace(-35, 26.6, 300)
sync_m = (10**22.5 * sync_r) * (1 + (sync_r/1e10)**1.25)
fig.add_trace(go.Scatter(x=sync_r, y=sync_m, name="LatticeLog LE Sync",
                         line=dict(color='#ff3300', width=5)))

# 3. Objects & Levers (Staggered)
points = {
    "Atoms": (1e-10, 1e-26, "#00ffff", "top center"),
    "Planets": (1e7, 1e25, "#00ffff", "middle left"),
    "Stars": (1e9, 1e30, "#00ffff", "middle right"),
    "Galaxies": (1e21, 1e42, "#00ffff", "middle left"),
    "Clusters": (1e23, 1e45, "#00ffff", "middle right"),
    "MICRO (11)": (1.6e-35, 2.2e-8, "#ffff00", "top center"),
    "FLEA (30)": (1e-3, 1e-5, "#ffff00", "middle left"),
    "LUNGS": (1, 70, "#ffff00", "middle right"),
}

for name, (r, m, color, pos) in points.items():
    fig.add_trace(go.Scatter(
        x=[r], y=[m], name=name, mode='markers+text',
        text=[f"<b>{name}</b>"], textposition=pos,
        marker=dict(color=color, size=12 if color=="#00ffff" else 18,
                    symbol='circle' if color=="#00ffff" else 'diamond'),
        textfont=dict(color=color, size=14)
    ))

# 4. Universe Gold Star
fig.add_trace(go.Scatter(
    x=[4.4e26], y=[1e54], name="THE UNIVERSE", mode='markers',
    marker=dict(color='gold', size=55, symbol='star', line=dict(width=2, color='black'))
))

# FIX: MACRO (19) LABEL POSITIONED HIGHER
fig.add_annotation(
    x=np.log10(4.4e26), y=np.log10(1e54),
    xref="x", yref="y",
    text="<b>MACRO (19)</b>",
    showarrow=False,
    yshift=80,  # Pushes label significantly higher than the star icon
    font=dict(color="#ffff00", size=22),
    bgcolor="rgba(0,0,0,0.8)",
    bordercolor="white",
    borderwidth=2,
    borderpad=6
)

# 5. Layout with Bottom Legend Buffer
fig.update_layout(
    title=dict(text=f"LatticeLogOS Grand Unification Chart<br><sup>Twisted Physics™ | {date_stamp}</sup>",
               x=0.5, font=dict(size=22, color='gold')),
    template="plotly_dark",
    xaxis_type="log", yaxis_type="log",
    xaxis=dict(title="Scale (Meters)", range=[-42, 34]),
    yaxis=dict(title="Mass (Kilograms)", range=[-48, 105]),

    # LEGEND FIX: Dropped even lower
    legend=dict(
        orientation="h",
        yanchor="top",
        y=-0.32,
        xanchor="center",
        x=0.5,
        font=dict(size=12),
        bgcolor="rgba(0,0,0,0)"
    ),

    margin=dict(l=60, r=60, t=100, b=280), # Large bottom margin for legend
    width=1100,
    height=950
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="bffddf7f-ef44-4c58-8153-31cd20ca4a6b" class="plotly-graph-div" style="height:950px; width:1100px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bffddf7f-ef44-4c58-8153-31cd20ca4a6b")) {                    Plotly.newPlot(                        "bffddf7f-ef44-4c58-8153-31cd20ca4a6b",                        [{"line":{"color":"white","dash":"dash","width":2},"name":"SCHWARZSCHILD LIMIT","x":[1e-45,1.446507338521653e-45,2.092383480396962e-45,3.026648059395683e-45,4.378068629038175e-45,6.332908400455153e-45,9.160598475443653e-45,1.3250872919979512e-44,1.9167484920568208e-44,2.7725907598605037e-44,4.0105728808554796e-44,5.801323103833378e-44,8.391656442830196e-44,1.213859262690619e-43,1.7558563314144633e-43,2.5398590687807293e-43,3.673924781802097e-43,5.3143591580532085e-43,7.